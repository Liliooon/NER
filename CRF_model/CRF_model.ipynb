# %%
# !wget https://raw.githubusercontent.com/Rexhaif/ner-dialogues-hackathon/master/data/train.conll
# !wget https://raw.githubusercontent.com/Rexhaif/ner-dialogues-hackathon/master/data/dev.conll
# !wget https://raw.githubusercontent.com/Rexhaif/ner-dialogues-hackathon/master/data/test.conll

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
import scipy
import eli5
import pymorphy2
import spacy
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

# %%
nlp = spacy.load("en_core_web_sm")

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
with open('train.conll') as train_f, open('test.conll') as test_f:
    train_str = train_f.read()
    test_str = test_f.read()

# %%
def get_word_pos(word, sent):
    pos = morph.parse(word[0])[0].tag.POS
    if not pos:
        i = sent.index(word)
        sent = ' '.join([tok[0] for tok in sent]).capitalize()
        doc = nlp(sent)
        pos = doc[i].pos_
    return pos

# %%
def parse_conll(conll_str):
    sents = [tuple(sent.split()) for sent in conll_str.split('\n\n')]
    splitted_sents = []
    for sent in sents:
        i = iter(sent)
        splitted_sents.append(list(zip(i, i)))
    parsed_sents = [[(word[0], get_word_pos(word, sent), word[1])
                     for word in sent] for sent in splitted_sents]
    return parsed_sents

# %%
train_sents = parse_conll(train_str)
test_sents = parse_conll(test_str)

# %%
train_sents
# Out:
# [[('спой', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('шоколад', 'NOUN', 'B-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('LItaliano', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('дэнан', 'NOUN', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'),
#   ('The', 'DET', 'B-SONG'),
#   ('House', 'NOUN', 'I-SONG'),
#   ('Of', 'ADP', 'I-SONG'),
#   ('The', 'DET', 'I-SONG'),
#   ('Rising', 'VERB', 'I-SONG'),
#   ('Sun', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('мэззи', 'NOUN', 'B-SINGER'),
#   ('ста', 'NUMR', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'O'), ('бородин', 'NOUN', 'B-COMPOSER')],
#  [('включи', 'VERB', 'O')],
#  [('спой', 'VERB', 'O'),
#   ('джордж', 'NOUN', 'B-COMPOSER'),
#   ('гершвин', 'NOUN', 'I-COMPOSER')],
#  [('расскажи', 'VERB', 'O'), ('мва', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'), ('Total', 'ADV', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'), ('уэмом', 'NOUN', 'B-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('в', 'PREP', 'B-SONG'),
#   ('последнюю', 'ADJF', 'I-SONG'),
#   ('осень', 'NOUN', 'I-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('ники', 'NOUN', 'B-SINGER'),
#   ('минаж', 'NOUN', 'I-SINGER')],
#  [('пой', 'VERB', 'O'), ('дыркин', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'), ('многоточи', 'VERB', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('эис', 'ADJ', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('What', 'PRON', 'B-SONG'),
#   ('Do', 'AUX', 'I-SONG'),
#   ('You', 'PRON', 'I-SONG'),
#   ('Want', 'VERB', 'I-SONG'),
#   ('From', 'ADP', 'I-SONG'),
#   ('Me', 'PRON', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('тэгэзар', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('демо', 'PRTS', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('Et', 'X', 'B-SONG'),
#   ('Si', 'X', 'I-SONG'),
#   ('Tu', 'PROPN', 'I-SONG'),
#   ('NExistais', 'NOUN', 'I-SONG'),
#   ('Pas', 'NOUN', 'I-SONG')],
#  [('зажги', 'VERB', 'O'), ('маврин', 'NOUN', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'),
#   ('George', 'VERB', 'B-SINGER'),
#   ('Harrison', 'NOUN', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('наутилус', 'NOUN', 'B-SINGER'),
#   ('помпилиус', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('пост', 'NOUN', 'B-FILM'),
#   ('скриптум', 'NOUN', 'I-FILM'),
#   ('я', 'NPRO', 'I-FILM'),
#   ('люблю', 'VERB', 'I-FILM'),
#   ('тебя', 'NPRO', 'I-FILM')],
#  [('играй', 'VERB', 'O'), ('шлюз', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('финци', 'NOUN', 'B-BOOK'),
#   ('контин', 'NOUN', 'I-BOOK')],
#  [('пой', 'VERB', 'O'),
#   ('лоа', 'ADJ', 'B-SINGER'),
#   ('лоа', 'NOUN', 'I-SINGER')],
#  [('включи', 'VERB', 'O'), ('евэ', 'NOUN', 'B-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Mooncake', 'ADJ', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('Les', 'VERB', 'B-SONG'),
#   ('Feuilles', 'NOUN', 'I-SONG'),
#   ('Mortes', 'NOUN', 'I-SONG')],
#  [('включи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('сю', 'INTJ', 'B-SONG'),
#   ('каприс', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('Kate', 'ADV', 'B-SINGER'),
#   ('Nash', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'), ('флаилиф', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Je', 'NOUN', 'B-SONG'),
#   ('Suis', 'ADJ', 'I-SONG'),
#   ('Malade', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('джанг', 'NOUN', 'B-SINGER'),
#   ('чанг', 'NOUN', 'I-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('Avec', 'X', 'B-SONG'),
#   ('Le', 'X', 'I-SONG'),
#   ('Temps', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('загадк', 'NOUN', 'B-BOOK'),
#   ('появлени', 'NOUN', 'I-BOOK')],
#  [('играй', 'VERB', 'O'),
#   ('владимир', 'NOUN', 'B-SINGER'),
#   ('высоцк', 'NOUN', 'I-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('кэлэфорниэ', 'NOUN', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('александр', 'NOUN', 'B-SINGER'),
#   ('степанов', 'NOUN', 'I-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('мартин', 'NOUN', 'B-SINGER'),
#   ('бойд', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('брейксру', 'NOUN', 'B-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Fort', 'ADJ', 'B-SINGER'),
#   ('Minor', 'ADJ', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Goodbye', 'NOUN', 'B-SONG'),
#   ('Yellow', 'ADJ', 'I-SONG'),
#   ('Brick', 'NOUN', 'I-SONG'),
#   ('Road', 'NOUN', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'), ('зульфикар', 'NOUN', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'),
#   ('фактор', 'NOUN', 'B-SINGER'),
#   ('страх', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('омерзительн', 'NOUN', 'B-FILM'),
#   ('восьмёрк', 'NOUN', 'I-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('мон', 'NOUN', 'B-SONG'),
#   ('фрэр', 'NOUN', 'I-SONG'),
#   ('ле', 'PRCL', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('жаном', 'NOUN', 'B-COMPOSER'),
#   ('батист', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('санты', 'NOUN', 'B-SONG')],
#  [('включи', 'VERB', 'O'),
#   ('Dottie', 'NOUN', 'B-SINGER'),
#   ('Danger', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('PPK', 'VERB', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Ruby', 'NOUN', 'B-SONG'),
#   ('Tuesday', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('диджэ', 'NOUN', 'B-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('ундервуд', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'), ('жасмин', 'NOUN', 'B-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('франсуаз', 'NOUN', 'B-SINGER'),
#   ('саган', 'NOUN', 'I-SINGER')],
#  [('спой', 'VERB', 'O'), ('вебером', 'NOUN', 'B-COMPOSER')],
#  [('пой', 'VERB', 'O'), ('бетховен', 'NOUN', 'B-COMPOSER')],
#  [('воспроизведи', 'VERB', 'O'), ('дубцов', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('жоа', 'VERB', 'B-SINGER'),
#   ('гимараэш', 'NOUN', 'I-SINGER'),
#   ('рос', 'VERB', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('Justice', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('анже', 'NOUN', 'B-SINGER'),
#   ('жиперск', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('дан', 'PRTS', 'B-SONG'),
#   ('ма', 'ADV', 'I-SONG'),
#   ('рю', 'PROPN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O')],
#  [('вруби', 'VERB', 'O'), ('боем', 'NOUN', 'B-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('лэунли', 'NOUN', 'B-SINGER'),
#   ('айланд', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('это', 'PRCL', 'B-SONG'),
#   ('здорово', 'INTJ', 'I-SONG')],
#  [('спой', 'VERB', 'O'), ('мальчиках', 'NOUN', 'B-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('тимма', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'), ('брандэнбург', 'NOUN', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O')],
#  [('проиграй', 'VERB', 'O')],
#  [('давай', 'VERB', 'O'),
#   ('уизом', 'NOUN', 'B-SINGER'),
#   ('калиф', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('песни', 'NOUN', 'O'),
#   ('из', 'PREP', 'O'),
#   ('фильма', 'NOUN', 'O'),
#   ('секс', 'NOUN', 'B-FILM'),
#   ('по', 'PREP', 'I-FILM'),
#   ('дружбе', 'NOUN', 'I-FILM')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('A', 'DET', 'B-SONG'),
#   ('Saucerful', 'NOUN', 'I-SONG'),
#   ('Of', 'ADP', 'I-SONG'),
#   ('Secrets', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('аи', 'NOUN', 'B-SONG'),
#   ('вонт', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('карлос', 'NOUN', 'B-SINGER'),
#   ('фуэнтес', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('эдипов', 'NOUN', 'B-SINGER'),
#   ('комплекс', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('произведение', 'NOUN', 'O'),
#   ('ля', 'NOUN', 'B-SONG'),
#   ('боэм', 'NOUN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('а', 'CONJ', 'B-SONG'),
#   ('туа', 'NOUN', 'I-SONG')],
#  [('вруби', 'VERB', 'O'), ('дэсэмбаристс', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('Evanescence', 'NOUN', 'B-SINGER')],
#  [('пой', 'VERB', 'O'), ('учител', 'NOUN', 'B-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('берджер', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('айрэ', 'NOUN', 'B-SONG')],
#  [('вруби', 'VERB', 'O'), ('RotFront', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('клаудио', 'NOUN', 'B-COMPOSER'),
#   ('монтеверди', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('Tear', 'VERB', 'B-SONG'),
#   ('It', 'PRON', 'I-SONG'),
#   ('Up', 'ADP', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('милэ', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Teo', 'NOUN', 'B-SONG'),
#   ('Torriatte', 'NOUN', 'I-SONG'),
#   ('Let', 'VERB', 'I-SONG'),
#   ('Us', 'PRON', 'I-SONG'),
#   ('Cling', 'VERB', 'I-SONG'),
#   ('Together', 'ADV', 'I-SONG')],
#  [('вруби', 'VERB', 'O'), ('мод', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'), ('снэу', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('мари', 'NOUN', 'B-SINGER'),
#   ('эджуорт', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('торб', 'NOUN', 'B-SINGER'),
#   ('на', 'PREP', 'I-SINGER'),
#   ('круче', 'COMP', 'I-SINGER')],
#  [('пой', 'VERB', 'O'), ('Placebo', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('жюл', 'NOUN', 'B-COMPOSER'),
#   ('массне', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('гоша', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('бизе', 'NOUN', 'B-COMPOSER')],
#  [('вруби', 'VERB', 'O'),
#   ('машин', 'NOUN', 'B-FILM'),
#   ('времен', 'NOUN', 'I-FILM')],
#  [('проиграй', 'VERB', 'O'),
#   ('Ich', 'NOUN', 'B-SONG'),
#   ('Will', 'AUX', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('мире', 'NOUN', 'B-FILM'),
#   ('два', 'NUMR', 'I-FILM')],
#  [('спой', 'VERB', 'O'),
#   ('габриел', 'NOUN', 'B-COMPOSER'),
#   ('форе', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('родион', 'NOUN', 'B-COMPOSER'),
#   ('константинович', 'NOUN', 'I-COMPOSER'),
#   ('щедрин', 'NOUN', 'I-COMPOSER')],
#  [('воспроизводим', 'VERB', 'O'), ('йорша', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'), ('альянс', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'), ('инна', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('антон', 'NOUN', 'B-COMPOSER'),
#   ('веберн', 'NOUN', 'I-COMPOSER')],
#  [('воспроизводим', 'VERB', 'O'), ('любви', 'NOUN', 'B-BOOK')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('N', 'CCONJ', 'B-SINGER'),
#   ('E', 'NOUN', 'I-SINGER'),
#   ('R', 'X', 'I-SINGER'),
#   ('D', 'NOUN', 'I-SINGER')],
#  [('включи', 'VERB', 'O'), ('де', 'PRCL', 'B-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('Per', 'ADP', 'B-SONG'),
#   ('Lucia', 'NOUN', 'I-SONG')],
#  [('пой', 'VERB', 'O'), ('Metallica', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('долго', 'ADVB', 'B-BOOK'),
#   ('прощани', 'NOUN', 'I-BOOK')],
#  [('спой', 'VERB', 'O'), ('ревность', 'NOUN', 'B-BOOK')],
#  [('пой', 'VERB', 'O'), ('пропаганда', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('ком', 'NPRO', 'B-SONG'),
#   ('иль', 'CONJ', 'I-SONG'),
#   ('диз', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('джони', 'NOUN', 'B-SINGER'),
#   ('мичал', 'ADJS', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('сердц', 'NOUN', 'B-BOOK'),
#   ('пармы', 'NOUN', 'I-BOOK')],
#  [('проиграй', 'VERB', 'O'),
#   ('королевств', 'NOUN', 'B-SONG'),
#   ('кривых', 'NOUN', 'I-SONG')],
#  [('включи', 'VERB', 'O'), ('шенберг', 'NOUN', 'B-COMPOSER')],
#  [('пой', 'VERB', 'O')],
#  [('воспроизведи', 'VERB', 'O'), ('Celos', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Mos', 'ADJ', 'B-SINGER'),
#   ('Def', 'NOUN', 'I-SINGER')],
#  [('спой', 'VERB', 'O'), ('маврин', 'NOUN', 'B-SINGER')],
#  [('включи', 'VERB', 'O'), ('Salut', 'VERB', 'B-SONG')],
#  [('включи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Comme', 'ADJ', 'B-SONG'),
#   ('Disait', 'NOUN', 'I-SONG'),
#   ('Mistinguett', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('хавьер', 'NOUN', 'B-SINGER'),
#   ('серкас', 'NOUN', 'I-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('Janelle', 'NOUN', 'B-SINGER'),
#   ('Monae', 'VERB', 'I-SINGER')],
#  [('вруби', 'VERB', 'O'), ('Belle', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('елен', 'NOUN', 'B-SINGER'),
#   ('терлеев', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'), ('некандишен', 'ADJS', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('The', 'DET', 'B-SINGER'),
#   ('Weeknd', 'NOUN', 'I-SINGER')],
#  [('вруби', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('электрофорез', 'NOUN', 'B-SINGER')],
#  [('играй', 'VERB', 'O'), ('бессонниц', 'NOUN', 'B-FILM')],
#  [('проиграй', 'VERB', 'O'),
#   ('Les', 'X', 'B-SONG'),
#   ('Feuilles', 'NOUN', 'I-SONG'),
#   ('Mortes', 'NOUN', 'I-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('жизни', 'NOUN', 'B-FILM'),
#   ('прекрасн', 'NOUN', 'I-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('волшебн', 'NOUN', 'B-BOOK'),
#   ('водиц', 'NOUN', 'I-BOOK')],
#  [('проиграй', 'VERB', 'O'), ('сепалтур', 'NOUN', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'),
#   ('Razor', 'NOUN', 'B-SINGER'),
#   ('Bois', 'VERB', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('секс', 'NOUN', 'B-BOOK'),
#   ('с', 'PREP', 'I-BOOK'),
#   ('вишн', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('брюс', 'NOUN', 'B-FILM'),
#   ('всемогущ', 'ADJS', 'I-FILM')],
#  [('играй', 'VERB', 'O'), ('литалиано', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('хатбрэйкер', 'NOUN', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('DoppelgangeR', 'ADV', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'),
#   ('книгу', 'NOUN', 'O'),
#   ('вещего', 'ADJF', 'B-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('тайиб', 'NOUN', 'B-SINGER'),
#   ('салих', 'NOUN', 'I-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('макс', 'NOUN', 'B-SINGER'),
#   ('иванов', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Welcome', 'NOUN', 'B-SONG'),
#   ('To', 'ADP', 'I-SONG'),
#   ('The', 'DET', 'I-SONG'),
#   ('Machine', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Fields', 'NOUN', 'B-SONG'),
#   ('Of', 'ADP', 'I-SONG'),
#   ('Gold', 'NOUN', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('черн', 'NOUN', 'B-SINGER'),
#   ('кофе', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('эха', 'NOUN', 'B-SONG'),
#   ('любви', 'NOUN', 'I-SONG')],
#  [('пой', 'VERB', 'O'), ('Flёur', 'NOUN', 'B-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('дорожку', 'NOUN', 'O'),
#   ('Bella', 'NOUN', 'B-SONG'),
#   ('Ciao', 'NOUN', 'I-SONG')],
#  [('включи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Donovan', 'ADJ', 'B-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('реку', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'), ('включи', 'VERB', 'O')],
#  [('проиграй', 'VERB', 'O'),
#   ('рихард', 'NOUN', 'B-COMPOSER'),
#   ('штраус', 'NOUN', 'I-COMPOSER')],
#  [('проиграй', 'VERB', 'O'),
#   ('Les', 'X', 'B-SONG'),
#   ('Feuilles', 'NOUN', 'I-SONG'),
#   ('Mortes', 'NOUN', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('чего', 'NPRO', 'B-FILM'),
#   ('хотят', 'VERB', 'I-FILM'),
#   ('женщины', 'NOUN', 'I-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('мизери', 'NOUN', 'B-FILM')],
#  [('спой', 'VERB', 'O'), ('памелы', 'NOUN', 'B-BOOK')],
#  [('вруби', 'VERB', 'O'), ('илектрик', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('чужой', 'ADJF', 'B-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('бэд', 'ADV', 'B-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('тихон', 'NOUN', 'B-COMPOSER'),
#   ('николаевич', 'NOUN', 'I-COMPOSER'),
#   ('хренников', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('кэнт', 'NOUN', 'B-SONG'),
#   ('стоп', 'INTJ', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'), ('поинт', 'NOUN', 'B-FILM')],
#  [('включи', 'VERB', 'O'),
#   ('одинок', 'ADJS', 'B-BOOK'),
#   ('лондонц', 'NOUN', 'I-BOOK')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('на', 'PREP', 'B-FILM'),
#   ('грани', 'NOUN', 'I-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('генрих', 'NOUN', 'B-COMPOSER'),
#   ('шютц', 'NOUN', 'I-COMPOSER')],
#  [('спой', 'VERB', 'O'), ('фантазер', 'NOUN', 'B-BOOK')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('ред', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('омбре', 'NOUN', 'B-SONG'),
#   ('перфекто', 'ADVB', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('одисея', 'NOUN', 'B-BOOK')],
#  [('давай', 'VERB', 'O'), ('послушаем', 'VERB', 'O')],
#  [('пой', 'VERB', 'O'),
#   ('капитан', 'NOUN', 'B-BOOK'),
#   ('врунгел', 'NOUN', 'I-BOOK')],
#  [('пой', 'VERB', 'O'),
#   ('You', 'PRON', 'B-SONG'),
#   ('Should', 'AUX', 'I-SONG'),
#   ('Be', 'AUX', 'I-SONG'),
#   ('Dancing', 'VERB', 'I-SONG')],
#  [('зажги', 'VERB', 'O'), ('треть', 'NOUN', 'B-FILM')],
#  [('давай', 'VERB', 'O'), ('виламатас', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('дома', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('ян', 'NOUN', 'B-COMPOSER'),
#   ('сибелиус', 'NOUN', 'I-COMPOSER')],
#  [('пой', 'VERB', 'O'),
#   ('The', 'DET', 'B-SINGER'),
#   ('Velvet', 'NOUN', 'I-SINGER'),
#   ('Underground', 'ADV', 'I-SINGER')],
#  [('вруби', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('эдвард', 'NOUN', 'B-SINGER'),
#   ('форстер', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Bad', 'ADJ', 'B-SONG'),
#   ('Romance', 'NOUN', 'I-SONG')],
#  [('включи', 'VERB', 'O')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('оффенбах', 'NOUN', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('но', 'CONJ', 'B-SONG'),
#   ('же', 'PRCL', 'I-SONG')],
#  [('проиграй', 'VERB', 'O'), ('наоборот', 'ADVB', 'B-BOOK')],
#  [('расскажи', 'VERB', 'O'), ('адаптац', 'NOUN', 'B-FILM')],
#  [('воспроизводим', 'VERB', 'O'), ('берджер', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Anti', 'ADJ', 'B-SINGER'),
#   ('Flag', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Une', 'NOUN', 'B-SONG'),
#   ('Vie', 'NOUN', 'I-SONG'),
#   ('DAmour', 'NOUN', 'I-SONG'),
#   ('композитора', 'NOUN', 'O'),
#   ('римск', 'NOUN', 'B-COMPOSER'),
#   ('корсаков', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('The', 'DET', 'B-SINGER'),
#   ('Script', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Comme', 'ADJ', 'B-SONG'),
#   ('Disait', 'NOUN', 'I-SONG'),
#   ('Mistinguett', 'NOUN', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'O'), ('синклэр', 'NOUN', 'B-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Have', 'AUX', 'B-SONG'),
#   ('You', 'PRON', 'I-SONG'),
#   ('Ever', 'ADV', 'I-SONG'),
#   ('Really', 'ADV', 'I-SONG'),
#   ('Loved', 'VERB', 'I-SONG'),
#   ('A', 'DET', 'I-SONG'),
#   ('Woman', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('дмитр', 'NOUN', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('алеся', 'NOUN', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('ReAnima', 'NOUN', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'), ('ривар', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('два', 'NUMR', 'B-BOOK'),
#   ('мороз', 'NOUN', 'I-BOOK')],
#  [('играй', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('эраунд', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('красн', 'NOUN', 'B-SINGER'),
#   ('дерево', 'NOUN', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('никола', 'NOUN', 'B-COMPOSER'),
#   ('мясковск', 'NOUN', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('ольг', 'NOUN', 'B-SINGER'),
#   ('арефьев', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('клин', 'NOUN', 'B-SONG'),
#   ('тагэза', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('чэнс', 'NOUN', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('бастой', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'), ('хауз', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('наутилус', 'NOUN', 'B-SINGER'),
#   ('помпилиус', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('дорожку', 'NOUN', 'O')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('стравинск', 'NOUN', 'B-COMPOSER')],
#  [('включи', 'VERB', 'O'),
#   ('счастливо', 'ADVB', 'B-FILM'),
#   ('число', 'NOUN', 'I-FILM'),
#   ('слевина', 'NOUN', 'I-FILM')],
#  [('включи', 'VERB', 'O'), ('жамэ', 'NOUN', 'B-SONG')],
#  [('включи', 'VERB', 'O'),
#   ('джозеф', 'NOUN', 'B-SINGER'),
#   ('фаррел', 'VERB', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('рук', 'NOUN', 'B-SINGER'),
#   ('вверх', 'ADVB', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Stumblin', 'NOUN', 'B-SONG'),
#   ('In', 'ADP', 'I-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('яну', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Mourir', 'NOUN', 'B-SONG'),
#   ('Sur', 'NOUN', 'I-SONG'),
#   ('Scene', 'NOUN', 'I-SONG')],
#  [('вруби', 'VERB', 'O'), ('хороший', 'ADJF', 'B-FILM')],
#  [('проиграй', 'VERB', 'O'),
#   ('жорж', 'NOUN', 'B-SINGER'),
#   ('амаду', 'NOUN', 'I-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('сара', 'NOUN', 'B-SONG'),
#   ('перке', 'NOUN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('Dont', 'AUX', 'B-SONG'),
#   ('Cry', 'PART', 'I-SONG')],
#  [('играй', 'VERB', 'O'), ('Horizon', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('произведение', 'NOUN', 'O'),
#   ('Les', 'PROPN', 'B-SONG'),
#   ('Hommes', 'VERB', 'I-SONG'),
#   ('Qui', 'NOUN', 'I-SONG'),
#   ('Passent', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'), ('винтаж', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('нэ', 'ADV', 'B-SONG'),
#   ('регрэт', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('джет', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('пёрселл', 'NOUN', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('жизни', 'NOUN', 'B-SONG'),
#   ('струны', 'NOUN', 'I-SONG')],
#  [('включи', 'VERB', 'O'), ('форсаж', 'NOUN', 'B-FILM')],
#  [('зажги', 'VERB', 'O'),
#   ('Il', 'ADP', 'B-SONG'),
#   ('Pleut', 'NOUN', 'I-SONG'),
#   ('Sur', 'NOUN', 'I-SONG'),
#   ('Bruxelles', 'NOUN', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('морис', 'NOUN', 'B-COMPOSER'),
#   ('равел', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('фаревэ', 'NOUN', 'B-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('гаэтано', 'NOUN', 'B-COMPOSER'),
#   ('доницетти', 'NOUN', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'O'),
#   ('BB', 'ADP', 'B-SINGER'),
#   ('King', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('фридерик', 'NOUN', 'B-COMPOSER'),
#   ('шопен', 'NOUN', 'I-COMPOSER')],
#  [('проиграй', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('July', 'NOUN', 'B-SONG'),
#   ('Morning', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('лоа', 'ADV', 'B-SINGER'),
#   ('лоа', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('басилаунэ', 'NOUN', 'B-SONG')],
#  [('проиграй', 'VERB', 'O'),
#   ('александр', 'NOUN', 'B-SINGER'),
#   ('вертинск', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('Punk', 'NOUN', 'B-SINGER'),
#   ('TV', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('иван', 'NOUN', 'B-SINGER'),
#   ('вазов', 'ADJS', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('элен', 'NOUN', 'B-SINGER'),
#   ('ферранте', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('I', 'PRON', 'B-SONG'),
#   ('Need', 'VERB', 'I-SONG'),
#   ('You', 'PRON', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('ногган', 'NOUN', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('александр', 'NOUN', 'B-SINGER'),
#   ('хемон', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('виагр', 'NOUN', 'B-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('альфред', 'NOUN', 'B-SINGER'),
#   ('дёблин', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('александр', 'NOUN', 'B-COMPOSER'),
#   ('тихонович', 'NOUN', 'I-COMPOSER'),
#   ('гречанинов', 'NOUN', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'O'), ('хиэр', 'NOUN', 'B-SONG')],
#  [('проиграй', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('рей', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'), ('бэк', 'VERB', 'B-SINGER')],
#  [('спой', 'VERB', 'O'), ('нублие', 'NOUN', 'B-SONG')],
#  [('проиграй', 'VERB', 'O'),
#   ('индиан', 'NOUN', 'B-FILM'),
#   ('джонс', 'NOUN', 'I-FILM'),
#   ('в', 'PREP', 'I-FILM'),
#   ('поиск', 'NOUN', 'I-FILM'),
#   ('утраченн', 'NOUN', 'I-FILM'),
#   ('ковчег', 'NOUN', 'I-FILM')],
#  [('проиграй', 'VERB', 'O'),
#   ('дженет', 'NOUN', 'B-SINGER'),
#   ('уинтерсон', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'), ('послушаем', 'VERB', 'O')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('ту', 'ADJF', 'B-SONG'),
#   ('лайв', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('The', 'DET', 'B-SINGER'),
#   ('Fray', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('дорожку', 'NOUN', 'O'),
#   ('ун', 'NOUN', 'B-SONG'),
#   ('ви', 'INTJ', 'I-SONG'),
#   ('дамур', 'NOUN', 'I-SONG')],
#  [('вруби', 'VERB', 'O'), ('монамур', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('на', 'PREP', 'B-SONG'),
#   ('кургане', 'NOUN', 'I-SONG')],
#  [('проиграй', 'VERB', 'O'), ('далимань', 'NOUN', 'B-SONG')],
#  [('пой', 'VERB', 'O')],
#  [('пой', 'VERB', 'O'),
#   ('произведение', 'NOUN', 'O'),
#   ('виват', 'INTJ', 'B-SONG'),
#   ('король', 'NOUN', 'I-SONG')],
#  [('пой', 'VERB', 'O'),
#   ('безумн', 'NOUN', 'B-FILM'),
#   ('макс', 'NOUN', 'I-FILM'),
#   ('два', 'NUMR', 'I-FILM')],
#  [('зажги', 'VERB', 'O'),
#   ('роберт', 'NOUN', 'B-COMPOSER'),
#   ('шуман', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('хьюго', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('сезар', 'NOUN', 'B-COMPOSER'),
#   ('франк', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('кам', 'NOUN', 'B-SONG'),
#   ('андан', 'PRTS', 'I-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('Il', 'ADP', 'B-SONG'),
#   ('Pleut', 'NOUN', 'I-SONG'),
#   ('Sur', 'NOUN', 'I-SONG'),
#   ('Bruxelles', 'NOUN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('Always', 'ADV', 'B-SONG'),
#   ('Somewhere', 'ADV', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('без', 'PREP', 'B-FILM'),
#   ('лица', 'NOUN', 'I-FILM')],
#  [('проиграй', 'VERB', 'O'), ('корелли', 'NOUN', 'B-COMPOSER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('ян', 'NOUN', 'B-SINGER'),
#   ('мартел', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('пикник', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Eagle', 'NOUN', 'B-SONG')],
#  [('зажги', 'VERB', 'O'), ('дворжак', 'NOUN', 'B-COMPOSER')],
#  [('пой', 'VERB', 'O'),
#   ('александр', 'NOUN', 'B-COMPOSER'),
#   ('бородин', 'NOUN', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'O'), ('мертвец', 'NOUN', 'B-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('альберт', 'NOUN', 'B-BOOK'),
#   ('и', 'CONJ', 'I-BOOK'),
#   ('якоб', 'NOUN', 'I-BOOK')],
#  [('играй', 'VERB', 'O'),
#   ('хуан', 'NOUN', 'B-SINGER'),
#   ('гойтисол', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('леош', 'NOUN', 'B-COMPOSER'),
#   ('яначек', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('падени', 'NOUN', 'B-BOOK'),
#   ('дома', 'NOUN', 'I-BOOK'),
#   ('ашер', 'NOUN', 'I-BOOK')],
#  [('играй', 'VERB', 'O'),
#   ('тонк', 'NOUN', 'B-SONG'),
#   ('рябина', 'NOUN', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'O'), ('Neutral', 'ADJ', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('книгу', 'NOUN', 'O'),
#   ('васили', 'NOUN', 'B-BOOK'),
#   ('тёркин', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('шапк', 'NOUN', 'B-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('песня', 'NOUN', 'B-SONG')],
#  [('пой', 'VERB', 'O'), ('фаворит', 'NOUN', 'B-BOOK')],
#  [('играй', 'VERB', 'O'), ('онеггер', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('джозеф', 'NOUN', 'B-SINGER'),
#   ('хеллер', 'NOUN', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('на', 'PREP', 'B-BOOK'),
#   ('маяк', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('волшебниц', 'NOUN', 'B-BOOK')],
#  [('расскажи', 'VERB', 'O'), ('пересреверт', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('рук', 'NOUN', 'B-SINGER'),
#   ('вверх', 'ADVB', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('генрих', 'NOUN', 'B-COMPOSER'),
#   ('шютц', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('ещё', 'ADVB', 'B-SONG')],
#  [('вруби', 'VERB', 'O'), ('дэнэн', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'), ('эво', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('энэмэл', 'NOUN', 'B-SINGER'),
#   ('калэктив', 'NOUN', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'O'), ('ниэунеит', 'NOUN', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('джулиан', 'NOUN', 'B-SINGER'),
#   ('барнс', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Ich', 'NOUN', 'B-SONG'),
#   ('Will', 'AUX', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('приключени', 'NOUN', 'B-BOOK'),
#   ('гекльберри', 'NOUN', 'I-BOOK'),
#   ('финн', 'NOUN', 'I-BOOK')],
#  [('вруби', 'VERB', 'O'), ('бернстайн', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'), ('малер', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Tu', 'PROPN', 'B-SONG'),
#   ('Es', 'CCONJ', 'I-SONG'),
#   ('Foutu', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('уэкс', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('джаком', 'NOUN', 'B-COMPOSER'),
#   ('пуччини', 'NOUN', 'I-COMPOSER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('сказка', 'NOUN', 'B-BOOK'),
#   ('о', 'PREP', 'I-BOOK')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('софи', 'NOUN', 'B-COMPOSER'),
#   ('асгатовн', 'NOUN', 'I-COMPOSER'),
#   ('губайдулин', 'NOUN', 'I-COMPOSER')],
#  [('расскажи', 'VERB', 'O'),
#   ('спокойн', 'NOUN', 'B-SONG'),
#   ('ночь', 'NOUN', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'), ('противостояни', 'NOUN', 'B-FILM')],
#  [('пой', 'VERB', 'O'),
#   ('красно', 'ADJS', 'B-BOOK'),
#   ('и', 'CONJ', 'I-BOOK'),
#   ('чёрно', 'NOUN', 'I-BOOK')],
#  [('расскажи', 'VERB', 'O'),
#   ('велик', 'ADJS', 'B-BOOK'),
#   ('гэтсби', 'NOUN', 'I-BOOK')],
#  [('расскажи', 'VERB', 'O'),
#   ('список', 'NOUN', 'B-FILM'),
#   ('шиндлер', 'NOUN', 'I-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('рейда', 'NOUN', 'B-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Le', 'X', 'B-SONG'),
#   ('Clown', 'VERB', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('королевск', 'NOUN', 'B-BOOK'),
#   ('сказка', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('исаак', 'NOUN', 'B-COMPOSER'),
#   ('осипович', 'NOUN', 'I-COMPOSER'),
#   ('дунаевск', 'NOUN', 'I-COMPOSER')],
#  [('включи', 'VERB', 'O'),
#   ('гавриил', 'NOUN', 'B-SINGER'),
#   ('троепольск', 'ADJF', 'I-SINGER')],
#  [('играй', 'VERB', 'O'), ('рамо', 'NOUN', 'B-COMPOSER')],
#  [('вруби', 'VERB', 'O'), ('дальмань', 'NOUN', 'B-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('басков', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('зонэ', 'NOUN', 'B-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('Equal', 'ADJ', 'B-SINGER'),
#   ('Minds', 'NOUN', 'I-SINGER'),
#   ('Theory', 'NOUN', 'I-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('зор', 'NOUN', 'B-SINGER'),
#   ('нил', 'NOUN', 'I-SINGER'),
#   ('хёрстон', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('песни', 'NOUN', 'O'),
#   ('из', 'PREP', 'O'),
#   ('фильма', 'NOUN', 'O'),
#   ('воздушн', 'NOUN', 'B-FILM'),
#   ('маршал', 'NOUN', 'I-FILM')],
#  [('пой', 'VERB', 'O'),
#   ('James', 'NOUN', 'B-SINGER'),
#   ('Blake', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'), ('дамор', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('гайдн', 'NOUN', 'B-COMPOSER')],
#  [('расскажи', 'VERB', 'O'),
#   ('Sara', 'NOUN', 'B-SONG'),
#   ('Perche', 'NOUN', 'I-SONG'),
#   ('Ti', 'NOUN', 'I-SONG'),
#   ('Amo', 'X', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('фильм', 'NOUN', 'O'),
#   ('джон', 'NOUN', 'B-FILM'),
#   ('уик', 'VERB', 'I-FILM'),
#   ('два', 'NUMR', 'I-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('малена', 'NOUN', 'B-FILM')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('рёйксопп', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('сториэ', 'NOUN', 'B-SONG'),
#   ('ди', 'PRCL', 'I-SONG'),
#   ('тути', 'NOUN', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('станислав', 'NOUN', 'B-COMPOSER'),
#   ('монюшко', 'NOUN', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'O'), ('килаз', 'NOUN', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'), ('дасаев', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('никола', 'NOUN', 'B-COMPOSER'),
#   ('метнер', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('карл', 'NOUN', 'B-COMPOSER'),
#   ('мари', 'NOUN', 'I-COMPOSER'),
#   ('фон', 'PRCL', 'I-COMPOSER'),
#   ('вебер', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('звезды', 'NOUN', 'B-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('калинов', 'ADJS', 'B-SINGER'),
#   ('мост', 'NOUN', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('Una', 'NOUN', 'B-SONG'),
#   ('Musica', 'NOUN', 'I-SONG'),
#   ('Brutal', 'ADV', 'I-SONG')],
#  [('спой', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('джованни', 'NOUN', 'B-COMPOSER'),
#   ('палестрина', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('лебедин', 'ADJS', 'B-SONG'),
#   ('верност', 'NOUN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('Et', 'X', 'B-SONG'),
#   ('Si', 'X', 'I-SONG'),
#   ('Tu', 'PROPN', 'I-SONG'),
#   ('NExistais', 'NOUN', 'I-SONG'),
#   ('Pas', 'NOUN', 'I-SONG')],
#  [('спой', 'VERB', 'O'),
#   ('джованни', 'NOUN', 'B-COMPOSER'),
#   ('палестрина', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('Desert', 'NOUN', 'B-SONG'),
#   ('Rose', 'VERB', 'I-SONG')],
#  [('зажги', 'VERB', 'O'), ('Amatory', 'ADJ', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('Rosenrot', 'VERB', 'B-SONG')],
#  [('спой', 'VERB', 'O'),
#   ('произведение', 'NOUN', 'O'),
#   ('последне', 'ADJS', 'B-SONG'),
#   ('письм', 'NOUN', 'I-SONG')],
#  [('спой', 'VERB', 'O'),
#   ('солом', 'NOUN', 'B-SINGER'),
#   ('беллоу', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('пером', 'NOUN', 'B-SINGER'),
#   ('энквист', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('артур', 'NOUN', 'B-COMPOSER'),
#   ('онеггер', 'NOUN', 'I-COMPOSER')],
#  [('играй', 'VERB', 'O'), ('молекул', 'NOUN', 'B-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Non', 'ADJ', 'B-SONG'),
#   ('Je', 'X', 'I-SONG'),
#   ('Ne', 'INTJ', 'I-SONG'),
#   ('Regrette', 'NOUN', 'I-SONG'),
#   ('Rien', 'NOUN', 'I-SONG'),
#   ('из', 'PREP', 'O'),
#   ('тузах', 'NOUN', 'B-FILM')],
#  [('расскажи', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('кемикл', 'NOUN', 'B-SINGER')],
#  [('включи', 'VERB', 'O'), ('мэйар', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('тринадцать', 'NUMR', 'B-FILM'),
#   ('друзей', 'NOUN', 'I-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('Et', 'NOUN', 'B-SONG'),
#   ('Pourtant', 'NOUN', 'I-SONG'),
#   ('J', 'NOUN', 'I-SONG'),
#   ('Ai', 'VERB', 'I-SONG'),
#   ('Froid', 'ADJ', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('аними', 'ADJF', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('рай', 'NOUN', 'B-BOOK')],
#  [('включи', 'VERB', 'O'), ('ершов', 'ADJS', 'B-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('Jordin', 'NOUN', 'B-SINGER'),
#   ('Sparks', 'VERB', 'I-SINGER')],
#  [('пой', 'VERB', 'O'), ('героя', 'NOUN', 'B-FILM')],
#  [('давай', 'VERB', 'O'), ('дубцов', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('книгу', 'NOUN', 'O'),
#   ('о', 'PREP', 'B-BOOK'),
#   ('любв', 'GRND', 'I-BOOK'),
#   ('и', 'CONJ', 'I-BOOK'),
#   ('мрак', 'NOUN', 'I-BOOK')],
#  [('воспроизводим', 'VERB', 'O'), ('трофимов', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('Je', 'PROPN', 'B-SONG'),
#   ('Veux', 'NOUN', 'I-SONG')],
#  [('проиграй', 'VERB', 'O'), ('Akado', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('луиз', 'NOUN', 'B-SINGER'),
#   ('мэй', 'NOUN', 'I-SINGER'),
#   ('олкот', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('вореи', 'NOUN', 'B-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('порой', 'ADVB', 'B-BOOK'),
#   ('нестерпимо', 'ADJS', 'I-BOOK'),
#   ('хочется', 'VERB', 'I-BOOK')],
#  [('вруби', 'VERB', 'O'),
#   ('бригадн', 'NOUN', 'B-SINGER'),
#   ('подряд', 'ADVB', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('фолкнер', 'NOUN', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('эль', 'PRCL', 'B-SONG'),
#   ('бимбо', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('же', 'PRCL', 'B-SONG'),
#   ('круа', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('миюк', 'NOUN', 'B-SINGER'),
#   ('мияб', 'VERB', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'), ('сибелиус', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('дорожку', 'NOUN', 'O'),
#   ('я', 'NPRO', 'B-SONG'),
#   ('люблю', 'VERB', 'I-SONG'),
#   ('тебя', 'NPRO', 'I-SONG'),
#   ('жизнь', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('дорожку', 'NOUN', 'O'),
#   ('рэуботс', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('мешей', 'NOUN', 'B-SINGER'),
#   ('селимович', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('эдгар', 'NOUN', 'B-SINGER'),
#   ('докторо', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('геро', 'NOUN', 'B-BOOK'),
#   ('нашего', 'ADJF', 'I-BOOK'),
#   ('времени', 'NOUN', 'I-BOOK')],
#  [('проиграй', 'VERB', 'O'), ('бер', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('Woman', 'NOUN', 'B-SONG'),
#   ('In', 'ADP', 'I-SONG'),
#   ('Love', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Les', 'NOUN', 'B-SONG'),
#   ('Hommes', 'VERB', 'I-SONG'),
#   ('Qui', 'NOUN', 'I-SONG'),
#   ('Passent', 'NOUN', 'I-SONG')],
#  [('спой', 'VERB', 'O'), ('Starman', 'NOUN', 'B-SONG')],
#  [('воспроизводим', 'VERB', 'O'), ('маяковск', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('титаник', 'NOUN', 'B-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('франка', 'NOUN', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('A', 'DET', 'B-SONG'),
#   ('Chaque', 'NOUN', 'I-SONG'),
#   ('Fois', 'NOUN', 'I-SONG'),
#   ('JY', 'CCONJ', 'I-SONG'),
#   ('Crois', 'NOUN', 'I-SONG')],
#  [('спой', 'VERB', 'O'), ('Matisyahu', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('лойко', 'NOUN', 'B-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('побег', 'NOUN', 'B-FILM'),
#   ('из', 'PREP', 'I-FILM'),
#   ('шоушенк', 'NOUN', 'I-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('Les', 'VERB', 'B-SONG'),
#   ('Valses', 'NOUN', 'I-SONG'),
#   ('De', 'ADP', 'I-SONG'),
#   ('Vienne', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('не', 'PRCL', 'B-SONG'),
#   ('говорите', 'VERB', 'I-SONG'),
#   ('мне', 'NPRO', 'I-SONG'),
#   ('прощай', 'VERB', 'I-SONG')],
#  [('проиграй', 'VERB', 'O'), ('рассел', 'VERB', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('эмин', 'NOUN', 'B-SINGER'),
#   ('оздамар', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('гаулдэн', 'NOUN', 'B-SONG')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('елен', 'NOUN', 'B-SINGER'),
#   ('терлеев', 'NOUN', 'I-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('дорогой', 'NOUN', 'B-SONG'),
#   ('куда', 'CONJ', 'I-SONG'),
#   ('ты', 'NPRO', 'I-SONG'),
#   ('едешь', 'VERB', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('коловрат', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('мендельсон', 'NOUN', 'B-COMPOSER'),
#   ('бартольди', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('Lamia', 'NOUN', 'B-SINGER'),
#   ('Vox', 'PROPN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('михаил', 'NOUN', 'B-SINGER'),
#   ('салтыков', 'NOUN', 'I-SINGER'),
#   ('щедрин', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('выход', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'), ('Salut', 'VERB', 'B-SONG')],
#  [('давай', 'VERB', 'O'), ('коммандо', 'NOUN', 'B-FILM')],
#  [('пой', 'VERB', 'O'),
#   ('все', 'PRCL', 'B-FILM'),
#   ('или', 'CONJ', 'I-FILM'),
#   ('ничего', 'ADVB', 'I-FILM')],
#  [('пой', 'VERB', 'O'), ('диджитализм', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('песни', 'NOUN', 'O'),
#   ('из', 'PREP', 'O'),
#   ('фильма', 'NOUN', 'O'),
#   ('воздушн', 'NOUN', 'B-FILM'),
#   ('тюрьм', 'NOUN', 'I-FILM')],
#  [('проиграй', 'VERB', 'O'),
#   ('харле', 'NOUN', 'B-FILM'),
#   ('дэвидсон', 'NOUN', 'I-FILM'),
#   ('и', 'CONJ', 'I-FILM'),
#   ('ковбо', 'ADJS', 'I-FILM'),
#   ('мальборо', 'NOUN', 'I-FILM')],
#  [('включи', 'VERB', 'O'), ('мэть', 'INFN', 'B-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('софи', 'NOUN', 'B-COMPOSER'),
#   ('губайдулин', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('песни', 'NOUN', 'B-SONG')],
#  [('расскажи', 'VERB', 'O'), ('иф', 'ADP', 'B-SONG'), ('ю', 'DET', 'I-SONG')],
#  [('включи', 'VERB', 'O'),
#   ('серге', 'NOUN', 'B-COMPOSER'),
#   ('рахманинов', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('дорожку', 'NOUN', 'O'),
#   ('салю', 'VERB', 'B-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('пассан', 'NOUN', 'B-SONG'),
#   ('композитора', 'NOUN', 'O'),
#   ('жорж', 'NOUN', 'B-COMPOSER'),
#   ('бизе', 'NOUN', 'I-COMPOSER')],
#  [('пой', 'VERB', 'O'), ('комбат', 'NOUN', 'B-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('ой', 'INTJ', 'B-SONG'),
#   ('хорошо', 'ADVB', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('иль', 'CONJ', 'B-SONG'),
#   ('сэм', 'NOUN', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('людвиг', 'NOUN', 'B-COMPOSER'),
#   ('ван', 'PRCL', 'I-COMPOSER'),
#   ('бетховен', 'NOUN', 'I-COMPOSER')],
#  [('спой', 'VERB', 'O'), ('многоточи', 'VERB', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O'), ('павел', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('все', 'PRCL', 'B-SONG'),
#   ('пройдет', 'VERB', 'I-SONG')],
#  [('спой', 'VERB', 'O'), ('первый', 'ADJF', 'B-FILM')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('Its', 'PRON', 'B-SONG'),
#   ('Only', 'ADJ', 'I-SONG'),
#   ('love', 'NOUN', 'I-SONG')],
#  [('пой', 'VERB', 'O'), ('же', 'PRCL', 'B-SONG')],
#  [('спой', 'VERB', 'O'),
#   ('We', 'PRON', 'B-SONG'),
#   ('Are', 'AUX', 'I-SONG'),
#   ('The', 'DET', 'I-SONG'),
#   ('Champions', 'NOUN', 'I-SONG')],
#  [('пой', 'VERB', 'O'),
#   ('промышленн', 'NOUN', 'B-SINGER'),
#   ('архитектур', 'NOUN', 'I-SINGER')],
#  [('включи', 'VERB', 'O'), ('блестящи', 'ADJS', 'B-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('тэрриатте', 'NOUN', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('дэвид', 'NOUN', 'B-SINGER'),
#   ('геммел', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('алеш', 'NOUN', 'B-BOOK'),
#   ('попович', 'NOUN', 'I-BOOK')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Dénaturé', 'NOUN', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('нютрал', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('генри', 'NOUN', 'B-SINGER'),
#   ('джеймс', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('кипелов', 'ADJS', 'B-SINGER'),
#   ('кипелов', 'ADJS', 'I-SINGER')],
#  [('пой', 'VERB', 'O'), ('братья', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('Summer', 'NOUN', 'B-SONG'),
#   ('Night', 'NOUN', 'I-SONG'),
#   ('City', 'NOUN', 'I-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('Nonna', 'NOUN', 'B-SINGER'),
#   ('Mordukova', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('захват', 'NOUN', 'B-BOOK'),
#   ('сингапур', 'NOUN', 'I-BOOK')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Tegan', 'NOUN', 'B-SINGER'),
#   ('And', 'CCONJ', 'I-SINGER'),
#   ('Sara', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Les', 'NOUN', 'B-SONG'),
#   ('Hommes', 'VERB', 'I-SONG'),
#   ('Qui', 'NOUN', 'I-SONG'),
#   ('Passent', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'), ('орфом', 'NOUN', 'B-COMPOSER')],
#  [('пой', 'VERB', 'O'), ('возрождени', 'VERB', 'B-BOOK')],
#  [('расскажи', 'VERB', 'O'),
#   ('домом', 'NOUN', 'B-SINGER'),
#   ('кукол', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'), ('ки', 'INTJ', 'B-SONG'), ('май', 'NOUN', 'I-SONG')],
#  [('пой', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Tesla', 'ADJ', 'B-SINGER'),
#   ('Boy', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('опиум', 'NOUN', 'B-SONG'),
#   ('для', 'PREP', 'I-SONG'),
#   ('никого', 'NPRO', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('жюл', 'NOUN', 'B-SINGER'),
#   ('верн', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'), ('уолден', 'NOUN', 'B-BOOK')],
#  [('пой', 'VERB', 'O'),
#   ('все', 'PRCL', 'B-SONG'),
#   ('пройдет', 'VERB', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Crowded', 'VERB', 'B-SINGER'),
#   ('House', 'NOUN', 'I-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('нэнси', 'NOUN', 'B-SINGER'),
#   ('митфорд', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Les', 'NOUN', 'B-SONG'),
#   ('Hommes', 'VERB', 'I-SONG'),
#   ('Qui', 'NOUN', 'I-SONG'),
#   ('Passent', 'NOUN', 'I-SONG'),
#   ('композитора', 'NOUN', 'O'),
#   ('арнольд', 'NOUN', 'B-COMPOSER'),
#   ('шёнберг', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('андьен', 'NOUN', 'B-SONG')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('рэнсид', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'), ('пикул', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('бизе', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('король', 'NOUN', 'B-BOOK'),
#   ('дроздобород', 'ADJS', 'I-BOOK')],
#  [('вруби', 'VERB', 'O'), ('салю', 'VERB', 'B-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('серге', 'NOUN', 'B-SINGER'),
#   ('трофимов', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('чайф', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('дё', 'NOUN', 'B-SONG'),
#   ('вьен', 'NOUN', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('Wax', 'NOUN', 'B-SINGER'),
#   ('Angel', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('антонин', 'NOUN', 'B-COMPOSER'),
#   ('дворжак', 'NOUN', 'I-COMPOSER')],
#  [('пой', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('мне', 'NPRO', 'B-FILM'),
#   ('бы', 'PRCL', 'I-FILM'),
#   ('в', 'PREP', 'I-FILM'),
#   ('небо', 'NOUN', 'I-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('алый', 'ADJF', 'B-SONG')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('франц', 'NOUN', 'B-COMPOSER'),
#   ('легар', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('севастопольск', 'NOUN', 'B-BOOK'),
#   ('рассказ', 'NOUN', 'I-BOOK')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('иоганн', 'NOUN', 'B-COMPOSER'),
#   ('бах', 'INTJ', 'I-COMPOSER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('дотти', 'ADJ', 'B-SINGER'),
#   ('дэйнджа', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O')],
#  [('расскажи', 'VERB', 'O'), ('Thrice', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('мадлен', 'NOUN', 'B-SINGER'),
#   ('лафайет', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('джеймс', 'NOUN', 'B-SINGER'),
#   ('кейн', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('вандал', 'NOUN', 'B-SINGER')],
#  [('вруби', 'VERB', 'O'), ('Atmoravi', 'NOUN', 'B-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('джованни', 'NOUN', 'B-COMPOSER'),
#   ('палестрина', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('дримар', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('знакомьтесь', 'VERB', 'B-FILM'),
#   ('джо', 'NOUN', 'I-FILM'),
#   ('блэк', 'NOUN', 'I-FILM')],
#  [('включи', 'VERB', 'O'),
#   ('I', 'PRON', 'B-SONG'),
#   ('Want', 'VERB', 'I-SONG'),
#   ('It', 'PRON', 'I-SONG'),
#   ('All', 'DET', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'O'), ('жуи', 'VERB', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Kola', 'NOUN', 'B-SINGER'),
#   ('Kid', 'NOUN', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'O'), ('амнезиа', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('судья', 'NOUN', 'B-FILM'),
#   ('дредд', 'NOUN', 'I-FILM')],
#  [('вруби', 'VERB', 'O'),
#   ('дэвид', 'NOUN', 'B-SINGER'),
# ...
#  [('воспроизведи', 'VERB', 'O'),
#   ('Mind', 'NOUN', 'B-SONG'),
#   ('Games', 'NOUN', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('оптимус', 'NOUN', 'B-SINGER'),
#   ('прайм', 'NOUN', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('лэизи', 'NOUN', 'B-SONG')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('кардигэнз', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('транквилизатор', 'NOUN', 'B-SONG')],
#  [('пой', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('онеггер', 'NOUN', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('A', 'DET', 'B-SONG'),
#   ('Qui', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'), ('видок', 'NOUN', 'B-FILM')],
#  [('играй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('елочн', 'NOUN', 'B-SINGER'),
#   ('игрушка', 'NOUN', 'I-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('кшиштоф', 'NOUN', 'B-COMPOSER'),
#   ('пендерецк', 'NOUN', 'I-COMPOSER')],
#  [('спой', 'VERB', 'O'), ('Sunny', 'ADJ', 'B-SONG')],
#  [('играй', 'VERB', 'O'), ('Rosenrot', 'ADJ', 'B-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('глюкоз', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('ай', 'INTJ', 'B-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('йозеф', 'NOUN', 'B-SINGER'),
#   ('шкворецк', 'NOUN', 'I-SINGER')],
#  [('вруби', 'VERB', 'O'), ('катюш', 'NOUN', 'B-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('маунтэн', 'NOUN', 'B-SINGER'),
#   ('гоутс', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('Alejandro', 'NOUN', 'B-SONG')],
#  [('воспроизводим', 'VERB', 'O'), ('киборг', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'), ('нелюбимую', 'ADJF', 'B-SONG')],
#  [('зажги', 'VERB', 'O'), ('день', 'NOUN', 'B-FILM')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Shakira', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('тони', 'NOUN', 'B-SINGER'),
#   ('моррисон', 'NOUN', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('джонатан', 'NOUN', 'B-SINGER'),
#   ('свифт', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('тринадцат', 'NOUN', 'B-FILM'),
#   ('район', 'NOUN', 'I-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('ностальжи', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'), ('доггом', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('minus', 'ADP', 'B-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('джонатан', 'NOUN', 'B-SINGER'),
#   ('фоер', 'NOUN', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('сеньор', 'NOUN', 'B-BOOK'),
#   ('президент', 'NOUN', 'I-BOOK')],
#  [('проиграй', 'VERB', 'O'), ('шенберг', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Optimus', 'VERB', 'B-SINGER'),
#   ('Prime', 'ADJ', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('игл', 'NOUN', 'B-SONG')],
#  [('проиграй', 'VERB', 'O'),
#   ('Boschs', 'NOUN', 'B-SINGER'),
#   ('With', 'ADP', 'I-SINGER'),
#   ('You', 'PRON', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('варум', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Septem', 'NOUN', 'B-SINGER'),
#   ('Voices', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('китте', 'NOUN', 'B-SONG'),
#   ('па', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'), ('рамо', 'NOUN', 'B-COMPOSER')],
#  [('воспроизведи', 'VERB', 'O'), ('готье', 'NOUN', 'B-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('тутти', 'NOUN', 'B-SONG'),
#   ('джорни', 'NOUN', 'I-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('маргарет', 'NOUN', 'B-SINGER'),
#   ('митчел', 'NOUN', 'I-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('Carla', 'VERB', 'B-SINGER'),
#   ('Bruni', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('на', 'PREP', 'B-BOOK'),
#   ('всяк', 'ADJS', 'I-BOOK'),
#   ('мудрец', 'NOUN', 'I-BOOK'),
#   ('довольно', 'ADVB', 'I-BOOK'),
#   ('простоты', 'NOUN', 'I-BOOK')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('абба', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('пансион', 'NOUN', 'B-BOOK'),
#   ('мирамар', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('книгу', 'NOUN', 'O'),
#   ('силе', 'NOUN', 'B-BOOK'),
#   ('и', 'CONJ', 'I-BOOK'),
#   ('слава', 'NOUN', 'I-BOOK')],
#  [('включи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('верди', 'NOUN', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('ихь', 'NOUN', 'B-SONG'),
#   ('виль', 'NOUN', 'I-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('дурн', 'NOUN', 'B-SINGER'),
#   ('влияни', 'VERB', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('луч', 'NOUN', 'B-SINGER')],
#  [('играй', 'VERB', 'O'), ('клевер', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('книгу', 'NOUN', 'O'),
#   ('дики', 'ADJS', 'B-BOOK'),
#   ('лебед', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('тихого', 'ADJF', 'B-BOOK')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('Hot', 'ADJ', 'B-SINGER'),
#   ('Chip', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('йу', 'ADP', 'B-SONG'), ('эва', 'INTJ', 'I-SONG')],
#  [('пой', 'VERB', 'O'), ('студжиз', 'NOUN', 'B-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('гори', 'VERB', 'B-SONG'),
#   ('гори', 'VERB', 'I-SONG'),
#   ('моя', 'ADJF', 'I-SONG'),
#   ('звезда', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('певца', 'NOUN', 'O'),
#   ('Nancy', 'NOUN', 'B-SINGER'),
#   ('Sinatra', 'NOUN', 'I-SINGER')],
#  [('вруби', 'VERB', 'O'), ('бетховен', 'NOUN', 'B-FILM')],
#  [('играй', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('монюшко', 'NOUN', 'B-COMPOSER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('ту', 'ADJF', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('моторам', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('король', 'NOUN', 'B-BOOK')],
#  [('спой', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('брет', 'NOUN', 'B-SINGER'),
#   ('эллис', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Je', 'NOUN', 'B-SONG'),
#   ('Suis', 'NOUN', 'I-SONG'),
#   ('Malade', 'NOUN', 'I-SONG')],
#  [('зажги', 'VERB', 'O')],
#  [('воспроизведи', 'VERB', 'O'), ('орбакайте', 'VERB', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('Addio', 'NOUN', 'B-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('Frank', 'ADJ', 'B-SINGER'),
#   ('Zappa', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'), ('штраус', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('умка', 'NOUN', 'B-SINGER')],
#  [('пой', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('франц', 'NOUN', 'B-COMPOSER'),
#   ('шуберт', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('это', 'PRCL', 'B-SONG'),
#   ('всё', 'PRCL', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('александр', 'NOUN', 'B-SINGER'),
#   ('беляев', 'NOUN', 'I-SINGER')],
#  [('зажги', 'VERB', 'O'), ('мари', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'), ('вивальди', 'NOUN', 'B-COMPOSER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('жаном', 'NOUN', 'B-COMPOSER'),
#   ('филипп', 'NOUN', 'I-COMPOSER'),
#   ('рамо', 'NOUN', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('сказочн', 'NOUN', 'B-SONG'),
#   ('тайг', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'),
#   ('арто', 'NOUN', 'B-SINGER'),
#   ('паасилин', 'NOUN', 'I-SINGER')],
#  [('расскажи', 'VERB', 'O'), ('переговорщик', 'NOUN', 'B-FILM')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Lei', 'X', 'B-SONG'),
#   ('Lei', 'X', 'I-SONG'),
#   ('композитора', 'NOUN', 'O'),
#   ('сен', 'NOUN', 'B-COMPOSER'),
#   ('санс', 'NOUN', 'I-COMPOSER')],
#  [('проиграй', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('аш', 'VERB', 'B-SINGER'),
#   ('компани', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('мутар', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('двенадцать', 'NUMR', 'B-BOOK'),
#   ('месяц', 'NOUN', 'I-BOOK')],
#  [('проиграй', 'VERB', 'O'), ('далимани', 'NOUN', 'B-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('соках', 'NOUN', 'B-BOOK'),
#   ('земли', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('мэид', 'NOUN', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('Belle', 'NOUN', 'B-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('Ploho', 'NOUN', 'B-SINGER')],
#  [('проиграй', 'VERB', 'O'), ('рамо', 'NOUN', 'B-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('весн', 'NOUN', 'B-SINGER'),
#   ('на', 'PREP', 'I-SINGER'),
#   ('улице', 'NOUN', 'I-SINGER'),
#   ('карл', 'NOUN', 'I-SINGER'),
#   ('юхан', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Insatiable', 'ADJ', 'B-SONG')],
#  [('спой', 'VERB', 'O'), ('Solerrain', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('повест', 'NOUN', 'B-BOOK'),
#   ('о', 'PREP', 'I-BOOK'),
#   ('жизни', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('верди', 'NOUN', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'O'),
#   ('письм', 'NOUN', 'B-SONG'),
#   ('в', 'PREP', 'I-SONG'),
#   ('редакцию', 'NOUN', 'I-SONG'),
#   ('телевизионной', 'ADJF', 'I-SONG'),
#   ('передачи', 'NOUN', 'I-SONG'),
#   ('очевидное', 'ADJF', 'I-SONG'),
#   ('невероятное', 'ADJF', 'I-SONG'),
#   ('из', 'PREP', 'I-SONG'),
#   ('сумасшедшего', 'ADJF', 'I-SONG'),
#   ('дома', 'NOUN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('богоматер', 'ADJS', 'B-BOOK'),
#   ('убийц', 'NOUN', 'I-BOOK')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('эшен', 'PRTS', 'B-SINGER'),
#   ('лайт', 'NOUN', 'I-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('бель', 'NOUN', 'B-SONG')],
#  [('расскажи', 'VERB', 'O'), ('краснознамённ', 'NOUN', 'B-SINGER')],
#  [('играй', 'VERB', 'O'), ('крэца', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('песни', 'NOUN', 'O'),
#   ('из', 'PREP', 'O'),
#   ('фильма', 'NOUN', 'O'),
#   ('игр', 'NOUN', 'B-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('Little', 'ADJ', 'B-SINGER'),
#   ('Big', 'ADJ', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('симон', 'NOUN', 'B-SINGER'),
#   ('вестдейк', 'NOUN', 'I-SINGER')],
#  [('проиграй', 'VERB', 'O'),
#   ('астерикс', 'NOUN', 'B-FILM'),
#   ('и', 'CONJ', 'I-FILM'),
#   ('обеликс', 'NOUN', 'I-FILM'),
#   ('клеопатр', 'NOUN', 'I-FILM')],
#  [('спой', 'VERB', 'O'), ('куа', 'NOUN', 'B-SONG')],
#  [('пой', 'VERB', 'O'), ('Origa', 'ADV', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('Ice', 'NOUN', 'B-SINGER'),
#   ('Cube', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'), ('конфесса', 'GRND', 'B-SONG')],
#  [('воспроизводим', 'VERB', 'O'), ('гуно', 'NOUN', 'B-COMPOSER')],
#  [('пой', 'VERB', 'O'), ('тихоня', 'NOUN', 'B-FILM')],
#  [('играй', 'VERB', 'O'), ('пэрке', 'NOUN', 'B-SONG')],
#  [('расскажи', 'VERB', 'O'), ('дио', 'ADJ', 'B-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('габриел', 'NOUN', 'B-COMPOSER'),
#   ('форе', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('гудзонск', 'NOUN', 'B-FILM'),
#   ('ястреб', 'NOUN', 'I-FILM')],
#  [('воспроизводим', 'VERB', 'O'), ('deadmau', 'NOUN', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('мореи', 'NOUN', 'B-SINGER'),
#   ('ил', 'NOUN', 'I-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('джеми', 'VERB', 'B-SINGER'),
#   ('онил', 'NOUN', 'I-SINGER')],
#  [('включи', 'VERB', 'O'),
#   ('софи', 'NOUN', 'B-COMPOSER'),
#   ('губайдулин', 'NOUN', 'I-COMPOSER')],
#  [('зажги', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('Et', 'NOUN', 'B-SONG'),
#   ('Pourtant', 'NOUN', 'I-SONG'),
#   ('J', 'NOUN', 'I-SONG'),
#   ('Ai', 'VERB', 'I-SONG'),
#   ('Froid', 'ADJ', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('я', 'NPRO', 'B-SONG'),
#   ('получил', 'VERB', 'I-SONG'),
#   ('эту', 'ADJF', 'I-SONG'),
#   ('роль', 'NOUN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('серге', 'NOUN', 'B-COMPOSER'),
#   ('рахманинов', 'NOUN', 'I-COMPOSER')],
#  [('спой', 'VERB', 'O'), ('эйнджэл', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'), ('крис', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('пэрфекто', 'ADVB', 'B-SONG'),
#   ('автора', 'NOUN', 'O'),
#   ('зощенко', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'), ('афра', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('двадцать', 'NUMR', 'B-FILM'),
#   ('один', 'ADJF', 'I-FILM'),
#   ('грамм', 'NOUN', 'I-FILM')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('House', 'NOUN', 'B-SINGER'),
#   ('Of', 'ADP', 'I-SINGER'),
#   ('Pain', 'NOUN', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('снайпер', 'NOUN', 'B-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('While', 'SCONJ', 'B-SONG'),
#   ('My', 'PRON', 'I-SONG'),
#   ('Guitar', 'NOUN', 'I-SONG'),
#   ('Gently', 'ADV', 'I-SONG'),
#   ('Weeps', 'VERB', 'I-SONG')],
#  [('расскажи', 'VERB', 'O'), ('BiopsyhoZ', 'NOUN', 'B-SINGER')],
#  [('зажги', 'VERB', 'O'),
#   ('аудиокнигу', 'NOUN', 'O'),
#   ('если', 'CONJ', 'B-BOOK'),
#   ('не', 'PRCL', 'I-BOOK'),
#   ('тепер', 'NOUN', 'I-BOOK')],
#  [('расскажи', 'VERB', 'O'), ('композитора', 'NOUN', 'O')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('мельниц', 'NOUN', 'B-SINGER')],
#  [('играй', 'VERB', 'O'),
#   ('Mamma', 'NOUN', 'B-SONG'),
#   ('Mia', 'NOUN', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'O'),
#   ('Tu', 'PROPN', 'B-SONG'),
#   ('Es', 'X', 'I-SONG'),
#   ('Foutu', 'NOUN', 'I-SONG')],
#  [('играй', 'VERB', 'O'), ('казанов', 'NOUN', 'B-SONG')],
#  [('расскажи', 'VERB', 'O'),
#   ('Tanha', 'VERB', 'B-SONG'),
#   ('Shodam', 'PROPN', 'I-SONG'),
#   ('El', 'NOUN', 'I-SONG'),
#   ('Bimbo', 'NOUN', 'I-SONG')],
#  [('вруби', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('Sakura', 'ADJ', 'B-SINGER'),
#   ('песню', 'NOUN', 'O'),
#   ('поплачь', 'VERB', 'B-SONG'),
#   ('о', 'PREP', 'I-SONG'),
#   ('нём', 'NPRO', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('St', 'ADV', 'B-SINGER'),
#   ('Petersburg', 'ADJ', 'I-SINGER'),
#   ('Ska', 'NOUN', 'I-SINGER'),
#   ('Jazz', 'NOUN', 'I-SINGER'),
#   ('Review', 'NOUN', 'I-SINGER')],
#  [('играй', 'VERB', 'O'), ('бэнни', 'NOUN', 'B-SINGER')],
#  [('спой', 'VERB', 'O'),
#   ('никола', 'NOUN', 'B-COMPOSER'),
#   ('яковлевич', 'NOUN', 'I-COMPOSER'),
#   ('мясковск', 'NOUN', 'I-COMPOSER')],
#  [('играй', 'VERB', 'O'),
#   ('песню', 'NOUN', 'O'),
#   ('All', 'DET', 'B-SONG'),
#   ('Those', 'DET', 'I-SONG'),
#   ('Years', 'NOUN', 'I-SONG'),
#   ('Ago', 'ADP', 'I-SONG'),
#   ('композитора', 'NOUN', 'O')],
#  [('зажги', 'VERB', 'O'), ('аркону', 'NOUN', 'B-SINGER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('идеальн', 'NOUN', 'B-FILM'),
#   ('шторм', 'NOUN', 'I-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('фэличит', 'VERB', 'B-SONG')],
#  [('расскажи', 'VERB', 'O'), ('стабом', 'NOUN', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('никому', 'NPRO', 'B-SONG'),
#   ('тебя', 'NPRO', 'I-SONG'),
#   ('я', 'NPRO', 'I-SONG'),
#   ('не', 'PRCL', 'I-SONG'),
#   ('отдам', 'VERB', 'I-SONG')],
#  [('пой', 'VERB', 'O'), ('два', 'NUMR', 'B-BOOK'), ('плуг', 'NOUN', 'I-BOOK')],
#  [('вруби', 'VERB', 'O'),
#   ('автора', 'NOUN', 'O'),
#   ('конец', 'NOUN', 'B-SINGER'),
#   ('фильма', 'NOUN', 'I-SINGER')],
#  [('пой', 'VERB', 'O'), ('муттэр', 'NOUN', 'B-SONG')],
#  [('пой', 'VERB', 'O'), ('руке', 'NOUN', 'B-FILM')],
#  [('спой', 'VERB', 'O'),
#   ('лео', 'NOUN', 'B-COMPOSER'),
#   ('делиб', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('из', 'PREP', 'O'),
#   ('дюна', 'NOUN', 'B-FILM'),
#   ('песню', 'NOUN', 'O'),
#   ('вуле', 'NOUN', 'B-SONG'),
#   ('ву', 'NOUN', 'I-SONG')],
#  [('давай', 'VERB', 'O'),
#   ('включи', 'VERB', 'O'),
#   ('двадцать', 'NUMR', 'B-FILM'),
#   ('один', 'ADJF', 'I-FILM'),
#   ('грамм', 'NOUN', 'I-FILM')],
#  [('давай', 'VERB', 'O'), ('нем', 'ADJS', 'B-SONG')],
#  [('проиграй', 'VERB', 'O'), ('да', 'PRCL', 'B-SONG')],
#  [('давай', 'VERB', 'O'), ('гайдн', 'NOUN', 'B-COMPOSER')],
#  [('воспроизводим', 'VERB', 'O'),
#   ('георг', 'NOUN', 'B-COMPOSER'),
#   ('гендел', 'VERB', 'I-COMPOSER')],
#  [('расскажи', 'VERB', 'O'), ('муттэр', 'NOUN', 'B-SONG')],
#  [('зажги', 'VERB', 'O'),
#   ('композитора', 'NOUN', 'O'),
#   ('людвиг', 'NOUN', 'B-COMPOSER'),
#   ('ван', 'PRCL', 'I-COMPOSER'),
#   ('бетховен', 'NOUN', 'I-COMPOSER')],
#  [('давай', 'VERB', 'O'),
#   ('послушаем', 'VERB', 'O'),
#   ('согдиан', 'NOUN', 'B-SINGER')],
#  [('расскажи', 'VERB', 'O'),
#   ('хаи', 'NOUN', 'B-SONG'),
#   ('хоупс', 'NOUN', 'I-SONG')],
#  ...]

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

# %%
X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %%
X_train[0][1]
# Out:
# {'bias': 1.0,
#  'word.lower()': 'из',
#  'word[-3:]': 'из',
#  'word.isupper()': False,
#  'word.istitle()': False,
#  'word.isdigit()': False,
#  'postag': 'PREP',
#  'postag[:2]': 'PR',
#  '-1:word.lower()': 'спой',
#  '-1:word.istitle()': False,
#  '-1:word.isupper()': False,
#  '-1:postag': 'VERB',
#  '-1:postag[:2]': 'VE',
#  '+1:word.lower()': 'шоколад',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False,
#  '+1:postag': 'NOUN',
#  '+1:postag[:2]': 'NO'}

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=20,
    all_possible_transitions=False,
)
crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_transitions=False, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=20)

# %%
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-BOOK</th>
#
#                 <th>I-BOOK</th>
#
#                 <th>B-COMPOSER</th>
#
#                 <th>I-COMPOSER</th>
#
#                 <th>B-FILM</th>
#
#                 <th>I-FILM</th>
#
#                 <th>B-SINGER</th>
#
#                 <th>I-SINGER</th>
#
#                 <th>B-SONG</th>
#
#                 <th>I-SONG</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.25%)" title="O &rArr; O">
#                             0.707
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.73%)" title="O &rArr; B-BOOK">
#                             2.192
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.50%)" title="O &rArr; B-COMPOSER">
#                             2.277
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.39%)" title="O &rArr; B-FILM">
#                             3.558
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 87.14%)" title="O &rArr; B-SINGER">
#                             4.117
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 83.41%)" title="O &rArr; B-SONG">
#                             5.922
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-SONG">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-BOOK</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.55%)" title="B-BOOK &rArr; I-BOOK">
#                             6.894
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-SONG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-SONG">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-BOOK</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 84.30%)" title="I-BOOK &rArr; I-BOOK">
#                             5.476
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-SONG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-SONG">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-COMPOSER</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.58%)" title="B-COMPOSER &rArr; O">
#                             -0.176
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-COMPOSER &rArr; B-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="backg

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-FILM',
#  'B-SONG',
#  'B-SINGER',
#  'I-SONG',
#  'I-SINGER',
#  'B-COMPOSER',
#  'I-COMPOSER',
#  'I-FILM',
#  'B-BOOK',
#  'I-BOOK']

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred,
                      average='weighted', labels=labels)
# Out:
# 0.6235860877360649

# %%
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#       B-BOOK      0.320     0.219     0.260        73
#       I-BOOK      0.381     0.416     0.398        89
#   B-COMPOSER      0.889     0.457     0.604        35
#   I-COMPOSER      0.667     0.571     0.615        21
#       B-FILM      0.720     0.261     0.383        69
#       I-FILM      0.724     0.356     0.477        59
#     B-SINGER      0.588     0.901     0.711       253
#     I-SINGER      0.581     0.782     0.667       147
#       B-SONG      0.831     0.594     0.693       165
#       I-SONG      0.865     0.734     0.794       192
#
#    micro avg      0.636     0.636     0.636      1103
#    macro avg      0.657     0.529     0.560      1103
# weighted avg      0.664     0.636     0.624      1103
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass labels=['B-BOOK', 'I-BOOK', 'B-COMPOSER', 'I-COMPOSER', 'B-FILM', 'I-FILM', 'B-SINGER', 'I-SINGER', 'B-SONG', 'I-SONG'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=100, 
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space, 
                        cv=3, 
                        verbose=1, 
                        n_jobs=-1, 
                        n_iter=50, 
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   14.5s finished
# RandomizedSearchCV(cv=3,
#                    estimator=CRF(algorithm='lbfgs',
#                                  all_possible_transitions=True,
#                                  keep_tempfiles=None, max_iterations=100),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'c1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x15e351cd0>,
#                                         'c2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x15f451d00>},
#                    scoring=make_scorer(flat_f1_score, average=weighted, labels=['B-FILM', 'B-SONG', 'B-SINGER', 'I-SONG', 'I-SINGER', 'B-COMPOSER', 'I-COMPOSER', 'I-FILM', 'B-BOOK', 'I-BOOK']),
#                    verbose=1)

# %%
# crf = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.0019015394428813202, 'c2': 0.1886651360699415}
# best CV score: 0.7483519860993625
# model size: 0.68M

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#       B-BOOK      0.553     0.288     0.378        73
#       I-BOOK      0.662     0.506     0.573        89
#   B-COMPOSER      0.818     0.514     0.632        35
#   I-COMPOSER      0.733     0.524     0.611        21
#       B-FILM      0.707     0.420     0.527        69
#       I-FILM      0.689     0.525     0.596        59
#     B-SINGER      0.609     0.874     0.718       253
#     I-SINGER      0.597     0.776     0.675       147
#       B-SONG      0.809     0.642     0.716       165
#       I-SONG      0.859     0.823     0.840       192
#
#    micro avg      0.687     0.684     0.685      1103
#    macro avg      0.704     0.589     0.627      1103
# weighted avg      0.701     0.684     0.676      1103

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# B-SINGER -> I-SINGER 5.548490
# B-SONG -> I-SONG  5.023144
# I-SONG -> I-SONG  4.905125
# B-BOOK -> I-BOOK  4.635808
# B-FILM -> I-FILM  4.413896
# I-FILM -> I-FILM  4.326321
# I-BOOK -> I-BOOK  4.210976
# I-SINGER -> I-SINGER 3.860774
# B-COMPOSER -> I-COMPOSER 3.822669
# I-COMPOSER -> I-COMPOSER 3.151252
# O      -> B-SONG  2.891483
# O      -> B-FILM  2.598696
# O      -> B-SINGER 1.904074
# O      -> B-BOOK  1.624749
# O      -> B-COMPOSER 1.461307
# I-SONG -> O       0.471503
# I-SINGER -> O       0.151076
# B-SINGER -> O       0.138368
# B-COMPOSER -> O       -0.023949
# O      -> O       -0.061645
#
# Top unlikely transitions:
# B-BOOK -> I-FILM  -0.801595
# B-COMPOSER -> I-BOOK  -0.860410
# I-SONG -> I-SINGER -0.866745
# B-SONG -> I-SINGER -0.879142
# B-SONG -> I-FILM  -0.917930
# B-COMPOSER -> I-FILM  -0.920273
# B-BOOK -> O       -0.937964
# B-FILM -> I-BOOK  -0.970867
# B-SONG -> I-BOOK  -0.972147
# B-SINGER -> I-BOOK  -1.000933
# B-SINGER -> I-FILM  -1.016942
# B-SINGER -> I-COMPOSER -1.108503
# I-SINGER -> I-SONG  -1.129236
# I-BOOK -> O       -1.133384
# B-SINGER -> I-SONG  -1.178205
# O      -> I-SONG  -1.995780
# O      -> I-COMPOSER -2.131756
# O      -> I-SINGER -2.250288
# O      -> I-FILM  -2.380203
# O      -> I-BOOK  -2.402410
