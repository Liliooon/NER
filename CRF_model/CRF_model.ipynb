# %%
# !wget https://raw.githubusercontent.com/Rexhaif/ner-dialogues-hackathon/master/data/train.conll
# !wget https://raw.githubusercontent.com/Rexhaif/ner-dialogues-hackathon/master/data/test.conll

# %%
! wget https://storage.yandexcloud.net/natasha-slovnet/packs/slovnet_syntax_news_v1.tar
! wget https://storage.yandexcloud.net/natasha-navec/packs/navec_news_v1_1B_250K_300d_100q.tar

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
import scipy
import eli5
import pymorphy2
import spacy
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
from navec import Navec
from slovnet import Syntax
from razdel import tokenize

# %%
navec = Navec.load('navec_news_v1_1B_250K_300d_100q.tar')
syntax = Syntax.load('slovnet_syntax_news_v1.tar')
syntax.navec(navec)

# %%
en_nlp = spacy.load("en_core_web_sm")

morph = pymorphy2.MorphAnalyzer()

# %%
with open('train.conll') as train_f, open('test.conll') as test_f:
    train_str = train_f.read()
    test_str = test_f.read()

# %%
def get_word_pos(word, sent, str_sent):
    pos = morph.parse(word[0])[0].tag.POS
    if not pos:
        i = sent.index(word)
        doc = en_nlp(str_sent)
        pos = doc[i].pos_
    return pos

# %%
def get_sent_syntax(sent):
    tokens = [_.text for _ in tokenize(sent)]
    markup = syntax(tokens)
    return [token.rel for token in markup.tokens]

# %%
def parse_conll(conll_str):
    sents = [tuple(sent.split()) for sent in conll_str.split('\n\n')]
    splitted_sents = []
    for i, sent in enumerate(sents):
        it = iter(sent)
        splitted_sents.append(list(zip(it, it)))

    parsed_sents = []
    for sent in splitted_sents:
        str_sent = ' '.join([tok[0] for tok in sent]).capitalize()
        if str_sent:
            parsed_sents.append([(word[0], get_word_pos(word, sent, str_sent), rel, word[1])
                                 for word, rel in zip(sent, get_sent_syntax(str_sent))])

    return parsed_sents

# %%
train_sents = parse_conll(train_str)
test_sents = parse_conll(test_str)

# %%
train_sents
# Out:
# [[('спой', 'VERB', 'acl', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('шоколад', 'NOUN', 'obl', 'B-FILM'),
#   ('песню', 'NOUN', 'appos', 'O'),
#   ('LItaliano', 'NOUN', 'appos', 'B-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('дэнан', 'NOUN', 'obj', 'B-SINGER')],
#  [('вруби', 'VERB', 'root', 'O'),
#   ('The', 'DET', 'appos', 'B-SONG'),
#   ('House', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Of', 'ADP', 'flat:foreign', 'I-SONG'),
#   ('The', 'DET', 'flat:foreign', 'I-SONG'),
#   ('Rising', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('Sun', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('мэззи', 'NOUN', 'obj', 'B-SINGER'),
#   ('ста', 'NUMR', 'nummod', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('бородин', 'NOUN', 'root', 'B-COMPOSER')],
#  [('включи', 'VERB', 'root', 'O')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('джордж', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('гершвин', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('расскажи', 'VERB', 'root', 'O'), ('мва', 'NOUN', 'obl', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'), ('Total', 'ADV', 'xcomp', 'B-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'), ('уэмом', 'NOUN', 'advmod', 'B-SINGER')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('в', 'PREP', 'case', 'B-SONG'),
#   ('последнюю', 'ADJF', 'amod', 'I-SONG'),
#   ('осень', 'NOUN', 'obl', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('ники', 'NOUN', 'obj', 'B-SINGER'),
#   ('минаж', 'NOUN', 'obj', 'I-SINGER')],
#  [('пой', 'VERB', 'root', 'O'), ('дыркин', 'NOUN', 'advmod', 'B-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('многоточи', 'VERB', 'advmod', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('эис', 'ADJ', 'amod', 'B-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('What', 'PRON', 'appos', 'B-SONG'),
#   ('Do', 'AUX', 'flat:foreign', 'I-SONG'),
#   ('You', 'PRON', 'flat:foreign', 'I-SONG'),
#   ('Want', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('From', 'ADP', 'flat:foreign', 'I-SONG'),
#   ('Me', 'PRON', 'flat:foreign', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('тэгэзар', 'NOUN', 'obj', 'B-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('демо', 'PRTS', 'obj', 'B-SINGER')],
#  [('проиграй', 'VERB', 'root', 'O'),
#   ('Et', 'X', 'appos', 'B-SONG'),
#   ('Si', 'X', 'flat:foreign', 'I-SONG'),
#   ('Tu', 'PROPN', 'flat:foreign', 'I-SONG'),
#   ('NExistais', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Pas', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O'), ('маврин', 'NOUN', 'nsubj', 'B-SINGER')],
#  [('вруби', 'VERB', 'root', 'O'),
#   ('George', 'VERB', 'appos', 'B-SINGER'),
#   ('Harrison', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('наутилус', 'NOUN', 'amod', 'B-SINGER'),
#   ('помпилиус', 'NOUN', 'appos', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('пост', 'NOUN', 'obj', 'B-FILM'),
#   ('скриптум', 'NOUN', 'nmod', 'I-FILM'),
#   ('я', 'NPRO', 'nsubj', 'I-FILM'),
#   ('люблю', 'VERB', 'root', 'I-FILM'),
#   ('тебя', 'NPRO', 'obj', 'I-FILM')],
#  [('играй', 'VERB', 'root', 'O'), ('шлюз', 'NOUN', 'advmod', 'B-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('финци', 'NOUN', 'iobj', 'B-BOOK'),
#   ('контин', 'NOUN', 'obl', 'I-BOOK')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('лоа', 'ADJ', 'root', 'B-SINGER'),
#   ('лоа', 'NOUN', 'obj', 'I-SINGER')],
#  [('включи', 'VERB', 'root', 'O'), ('евэ', 'NOUN', 'advmod', 'B-SINGER')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('Mooncake', 'ADJ', 'appos', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'root', 'O'),
#   ('Les', 'VERB', 'appos', 'B-SONG'),
#   ('Feuilles', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Mortes', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('включи', 'VERB', 'acl', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('сю', 'INTJ', 'nmod', 'B-SONG'),
#   ('каприс', 'NOUN', 'amod', 'I-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('Kate', 'ADV', 'appos', 'B-SINGER'),
#   ('Nash', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('играй', 'VERB', 'root', 'O'), ('флаилиф', 'NOUN', 'advmod', 'B-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Je', 'NOUN', 'appos', 'B-SONG'),
#   ('Suis', 'ADJ', 'flat:foreign', 'I-SONG'),
#   ('Malade', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('джанг', 'NOUN', 'amod', 'B-SINGER'),
#   ('чанг', 'NOUN', 'nsubj', 'I-SINGER')],
#  [('спой', 'VERB', 'root', 'O'),
#   ('Avec', 'X', 'appos', 'B-SONG'),
#   ('Le', 'X', 'flat:foreign', 'I-SONG'),
#   ('Temps', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('загадк', 'NOUN', 'xcomp', 'B-BOOK'),
#   ('появлени', 'NOUN', 'obj', 'I-BOOK')],
#  [('играй', 'VERB', 'advmod', 'O'),
#   ('владимир', 'NOUN', 'root', 'B-SINGER'),
#   ('высоцк', 'NOUN', 'punct', 'I-SINGER')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('кэлэфорниэ', 'NOUN', 'nmod', 'B-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('александр', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('степанов', 'NOUN', 'appos', 'I-SINGER')],
#  [('включи', 'VERB', 'acl', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('мартин', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('бойд', 'NOUN', 'appos', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('брейксру', 'NOUN', 'nmod', 'B-SONG')],
#  [('вруби', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('Fort', 'ADJ', 'appos', 'B-SINGER'),
#   ('Minor', 'ADJ', 'flat:foreign', 'I-SINGER'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('Goodbye', 'NOUN', 'appos', 'B-SONG'),
#   ('Yellow', 'ADJ', 'flat:foreign', 'I-SONG'),
#   ('Brick', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Road', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('зульфикар', 'NOUN', 'advmod', 'B-SINGER')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('фактор', 'NOUN', 'obj', 'B-SINGER'),
#   ('страх', 'NOUN', 'nmod', 'I-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('омерзительн', 'NOUN', 'amod', 'B-FILM'),
#   ('восьмёрк', 'NOUN', 'amod', 'I-FILM'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('мон', 'NOUN', 'amod', 'B-SONG'),
#   ('фрэр', 'NOUN', 'amod', 'I-SONG'),
#   ('ле', 'PRCL', 'appos', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('жаном', 'NOUN', 'nmod', 'B-COMPOSER'),
#   ('батист', 'NOUN', 'root', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('санты', 'NOUN', 'nmod', 'B-SONG')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('Dottie', 'NOUN', 'appos', 'B-SINGER'),
#   ('Danger', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('PPK', 'VERB', 'nmod', 'B-SINGER'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('Ruby', 'NOUN', 'appos', 'B-SONG'),
#   ('Tuesday', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('диджэ', 'NOUN', 'nmod', 'B-SINGER')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('ундервуд', 'NOUN', 'nmod', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'), ('жасмин', 'NOUN', 'obj', 'B-SINGER')],
#  [('включи', 'VERB', 'amod', 'O'),
#   ('франсуаз', 'NOUN', 'obj', 'B-SINGER'),
#   ('саган', 'NOUN', 'obj', 'I-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'), ('вебером', 'NOUN', 'advmod', 'B-COMPOSER')],
#  [('пой', 'VERB', 'root', 'O'), ('бетховен', 'NOUN', 'appos', 'B-COMPOSER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('дубцов', 'NOUN', 'advmod', 'B-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('жоа', 'VERB', 'amod', 'B-SINGER'),
#   ('гимараэш', 'NOUN', 'nsubj', 'I-SINGER'),
#   ('рос', 'VERB', 'root', 'I-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'), ('Justice', 'NOUN', 'obl', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('анже', 'NOUN', 'obj', 'B-SINGER'),
#   ('жиперск', 'NOUN', 'obj', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'iobj', 'O'),
#   ('дан', 'PRTS', 'root', 'B-SONG'),
#   ('ма', 'ADV', 'nsubj', 'I-SONG'),
#   ('рю', 'PROPN', 'nmod', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'root', 'O')],
#  [('вруби', 'VERB', 'amod', 'O'), ('боем', 'NOUN', 'obl', 'B-SINGER')],
#  [('пой', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('лэунли', 'NOUN', 'root', 'B-SINGER'),
#   ('айланд', 'NOUN', 'amod', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('это', 'PRCL', 'obj', 'B-SONG'),
#   ('здорово', 'INTJ', 'advmod', 'I-SONG')],
#  [('спой', 'VERB', 'amod', 'O'), ('мальчиках', 'NOUN', 'obl', 'B-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('тимма', 'NOUN', 'nmod', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('брандэнбург', 'NOUN', 'advmod', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'root', 'O')],
#  [('проиграй', 'VERB', 'root', 'O')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('уизом', 'NOUN', 'xcomp', 'B-SINGER'),
#   ('калиф', 'NOUN', 'obj', 'I-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('песни', 'NOUN', 'obj', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('фильма', 'NOUN', 'nmod', 'O'),
#   ('секс', 'NOUN', 'obj', 'B-FILM'),
#   ('по', 'PREP', 'case', 'I-FILM'),
#   ('дружбе', 'NOUN', 'nmod', 'I-FILM')],
#  [('воспроизведи', 'VERB', 'root', 'O'),
#   ('A', 'DET', 'appos', 'B-SONG'),
#   ('Saucerful', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Of', 'ADP', 'flat:foreign', 'I-SONG'),
#   ('Secrets', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('аи', 'NOUN', 'obj', 'B-SONG'),
#   ('вонт', 'NOUN', 'obj', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('карлос', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('фуэнтес', 'NOUN', 'appos', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('эдипов', 'NOUN', 'amod', 'B-SINGER'),
#   ('комплекс', 'NOUN', 'obj', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('произведение', 'NOUN', 'nsubj', 'O'),
#   ('ля', 'NOUN', 'nmod', 'B-SONG'),
#   ('боэм', 'NOUN', 'nmod', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('а', 'CONJ', 'cc', 'B-SONG'),
#   ('туа', 'NOUN', 'amod', 'I-SONG')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('дэсэмбаристс', 'NOUN', 'advmod', 'B-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('Evanescence', 'NOUN', 'obj', 'B-SINGER')],
#  [('пой', 'VERB', 'root', 'O'), ('учител', 'NOUN', 'advmod', 'B-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('берджер', 'NOUN', 'nmod', 'B-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('айрэ', 'NOUN', 'nmod', 'B-SONG')],
#  [('вруби', 'VERB', 'root', 'O'), ('RotFront', 'NOUN', 'appos', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'nsubj', 'O'),
#   ('композитора', 'NOUN', 'nmod', 'O'),
#   ('клаудио', 'NOUN', 'nmod', 'B-COMPOSER'),
#   ('монтеверди', 'NOUN', 'root', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Tear', 'VERB', 'appos', 'B-SONG'),
#   ('It', 'PRON', 'flat:foreign', 'I-SONG'),
#   ('Up', 'ADP', 'flat:foreign', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('милэ', 'NOUN', 'amod', 'B-SINGER'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('Teo', 'NOUN', 'appos', 'B-SONG'),
#   ('Torriatte', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Let', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('Us', 'PRON', 'flat:foreign', 'I-SONG'),
#   ('Cling', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('Together', 'ADV', 'flat:foreign', 'I-SONG')],
#  [('вруби', 'VERB', 'amod', 'O'), ('мод', 'NOUN', 'nmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'), ('снэу', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('мари', 'NOUN', 'obj', 'B-SINGER'),
#   ('эджуорт', 'NOUN', 'advmod', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('торб', 'NOUN', 'obj', 'B-SINGER'),
#   ('на', 'PREP', 'case', 'I-SINGER'),
#   ('круче', 'COMP', 'advmod', 'I-SINGER')],
#  [('пой', 'VERB', 'root', 'O'), ('Placebo', 'NOUN', 'appos', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('жюл', 'NOUN', 'obj', 'B-COMPOSER'),
#   ('массне', 'NOUN', 'obj', 'I-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('гоша', 'NOUN', 'nsubj', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('бизе', 'NOUN', 'obj', 'B-COMPOSER')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('машин', 'NOUN', 'nmod', 'B-FILM'),
#   ('времен', 'NOUN', 'nmod', 'I-FILM')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('Ich', 'NOUN', 'appos', 'B-SONG'),
#   ('Will', 'AUX', 'flat:foreign', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('мире', 'NOUN', 'obj', 'B-FILM'),
#   ('два', 'NUMR', 'advmod', 'I-FILM')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('габриел', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('форе', 'NOUN', 'nmod', 'I-COMPOSER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('родион', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('константинович', 'NOUN', 'appos', 'I-COMPOSER'),
#   ('щедрин', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('йорша', 'NOUN', 'advmod', 'B-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'), ('альянс', 'NOUN', 'root', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'), ('инна', 'NOUN', 'nsubj', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('антон', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('веберн', 'NOUN', 'nsubj', 'I-COMPOSER')],
#  [('воспроизводим', 'VERB', 'root', 'O'), ('любви', 'NOUN', 'iobj', 'B-BOOK')],
#  [('воспроизведи', 'VERB', 'root', 'O'),
#   ('N', 'CCONJ', 'appos', 'B-SINGER'),
#   ('E', 'NOUN', 'flat:foreign', 'I-SINGER'),
#   ('R', 'X', 'flat:foreign', 'I-SINGER'),
#   ('D', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('включи', 'VERB', 'root', 'O'), ('де', 'PRCL', 'advmod', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('Per', 'ADP', 'appos', 'B-SONG'),
#   ('Lucia', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('пой', 'VERB', 'root', 'O'), ('Metallica', 'NOUN', 'appos', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('долго', 'ADVB', 'advmod', 'B-BOOK'),
#   ('прощани', 'NOUN', 'advmod', 'I-BOOK')],
#  [('спой', 'VERB', 'amod', 'O'), ('ревность', 'NOUN', 'root', 'B-BOOK')],
#  [('пой', 'VERB', 'root', 'O'), ('пропаганда', 'NOUN', 'advmod', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('ком', 'NPRO', 'advmod', 'B-SONG'),
#   ('иль', 'CONJ', 'amod', 'I-SONG'),
#   ('диз', 'NOUN', 'nmod', 'I-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('джони', 'NOUN', 'nmod', 'B-SINGER'),
#   ('мичал', 'ADJS', 'appos', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('сердц', 'NOUN', 'obj', 'B-BOOK'),
#   ('пармы', 'NOUN', 'obj', 'I-BOOK')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('королевств', 'NOUN', 'amod', 'B-SONG'),
#   ('кривых', 'NOUN', 'nmod', 'I-SONG')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('шенберг', 'NOUN', 'advmod', 'B-COMPOSER')],
#  [('пой', 'VERB', 'root', 'O')],
#  [('воспроизведи', 'VERB', 'root', 'O'), ('Celos', 'NOUN', 'appos', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('Mos', 'ADJ', 'obj', 'B-SINGER'),
#   ('Def', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'), ('маврин', 'NOUN', 'root', 'B-SINGER')],
#  [('включи', 'VERB', 'root', 'O'), ('Salut', 'VERB', 'appos', 'B-SONG')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Comme', 'ADJ', 'appos', 'B-SONG'),
#   ('Disait', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Mistinguett', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('хавьер', 'NOUN', 'appos', 'B-SINGER'),
#   ('серкас', 'NOUN', 'appos', 'I-SINGER')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('Janelle', 'NOUN', 'appos', 'B-SINGER'),
#   ('Monae', 'VERB', 'flat:foreign', 'I-SINGER')],
#  [('вруби', 'VERB', 'appos', 'O'), ('Belle', 'NOUN', 'appos', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('певца', 'NOUN', 'obj', 'O'),
#   ('елен', 'NOUN', 'obj', 'B-SINGER'),
#   ('терлеев', 'NOUN', 'iobj', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('некандишен', 'ADJS', 'advmod', 'B-SINGER')],
#  [('проиграй', 'VERB', 'root', 'O'),
#   ('певца', 'NOUN', 'nmod', 'O'),
#   ('The', 'DET', 'appos', 'B-SINGER'),
#   ('Weeknd', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('вруби', 'VERB', 'nsubj', 'O'),
#   ('певца', 'NOUN', 'nmod', 'O'),
#   ('электрофорез', 'NOUN', 'nmod', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'), ('бессонниц', 'NOUN', 'advmod', 'B-FILM')],
#  [('проиграй', 'VERB', 'root', 'O'),
#   ('Les', 'X', 'appos', 'B-SONG'),
#   ('Feuilles', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Mortes', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('жизни', 'NOUN', 'obj', 'B-FILM'),
#   ('прекрасн', 'NOUN', 'iobj', 'I-FILM')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('волшебн', 'NOUN', 'amod', 'B-BOOK'),
#   ('водиц', 'NOUN', 'obj', 'I-BOOK')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('сепалтур', 'NOUN', 'advmod', 'B-SINGER')],
#  [('вруби', 'VERB', 'root', 'O'),
#   ('Razor', 'NOUN', 'appos', 'B-SINGER'),
#   ('Bois', 'VERB', 'flat:foreign', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('секс', 'NOUN', 'obj', 'B-BOOK'),
#   ('с', 'PREP', 'case', 'I-BOOK'),
#   ('вишн', 'NOUN', 'nmod', 'I-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('брюс', 'NOUN', 'nsubj', 'B-FILM'),
#   ('всемогущ', 'ADJS', 'amod', 'I-FILM')],
#  [('играй', 'VERB', 'root', 'O'), ('литалиано', 'NOUN', 'advmod', 'B-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('хатбрэйкер', 'NOUN', 'nmod', 'B-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('DoppelgangeR', 'ADV', 'appos', 'B-SINGER')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('книгу', 'NOUN', 'obj', 'O'),
#   ('вещего', 'ADJF', 'nmod', 'B-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('певца', 'NOUN', 'obj', 'O'),
#   ('тайиб', 'NOUN', 'root', 'B-SINGER'),
#   ('салих', 'NOUN', 'nsubj', 'I-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('макс', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('иванов', 'NOUN', 'root', 'I-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('Welcome', 'NOUN', 'appos', 'B-SONG'),
#   ('To', 'ADP', 'flat:foreign', 'I-SONG'),
#   ('The', 'DET', 'flat:foreign', 'I-SONG'),
#   ('Machine', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('Fields', 'NOUN', 'appos', 'B-SONG'),
#   ('Of', 'ADP', 'flat:foreign', 'I-SONG'),
#   ('Gold', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('черн', 'NOUN', 'amod', 'B-SINGER'),
#   ('кофе', 'NOUN', 'nmod', 'I-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('эха', 'NOUN', 'obj', 'B-SONG'),
#   ('любви', 'NOUN', 'nmod', 'I-SONG')],
#  [('пой', 'VERB', 'root', 'O'), ('Flёur', 'NOUN', 'appos', 'B-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('дорожку', 'NOUN', 'obj', 'O'),
#   ('Bella', 'NOUN', 'appos', 'B-SONG'),
#   ('Ciao', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('Donovan', 'ADJ', 'appos', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('реку', 'NOUN', 'nmod', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'), ('включи', 'VERB', 'advmod', 'O')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('рихард', 'NOUN', 'appos', 'B-COMPOSER'),
#   ('штраус', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('проиграй', 'VERB', 'root', 'O'),
#   ('Les', 'X', 'appos', 'B-SONG'),
#   ('Feuilles', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Mortes', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('чего', 'NPRO', 'obj', 'B-FILM'),
#   ('хотят', 'VERB', 'xcomp', 'I-FILM'),
#   ('женщины', 'NOUN', 'nsubj', 'I-FILM')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('мизери', 'NOUN', 'obj', 'B-FILM')],
#  [('спой', 'VERB', 'amod', 'O'), ('памелы', 'NOUN', 'nmod', 'B-BOOK')],
#  [('вруби', 'VERB', 'amod', 'O'), ('илектрик', 'NOUN', 'advmod', 'B-SINGER')],
#  [('проиграй', 'VERB', 'acl', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('чужой', 'ADJF', 'amod', 'B-FILM'),
#   ('песню', 'NOUN', 'obl', 'O'),
#   ('бэд', 'ADV', 'nmod', 'B-SONG')],
#  [('зажги', 'VERB', 'amod', 'O'),
#   ('тихон', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('николаевич', 'NOUN', 'appos', 'I-COMPOSER'),
#   ('хренников', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('кэнт', 'NOUN', 'amod', 'B-SONG'),
#   ('стоп', 'INTJ', 'obj', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('поинт', 'NOUN', 'advmod', 'B-FILM')],
#  [('включи', 'VERB', 'nsubj', 'O'),
#   ('одинок', 'ADJS', 'root', 'B-BOOK'),
#   ('лондонц', 'NOUN', 'advmod', 'I-BOOK')],
#  [('воспроизводим', 'VERB', 'root', 'O'),
#   ('на', 'PREP', 'case', 'B-FILM'),
#   ('грани', 'NOUN', 'obl', 'I-FILM')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('генрих', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('шютц', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('спой', 'VERB', 'amod', 'O'), ('фантазер', 'NOUN', 'advmod', 'B-BOOK')],
#  [('воспроизводим', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('ред', 'NOUN', 'nmod', 'B-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('омбре', 'NOUN', 'root', 'B-SONG'),
#   ('перфекто', 'ADVB', 'obj', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('одисея', 'NOUN', 'obj', 'B-BOOK')],
#  [('давай', 'VERB', 'advmod', 'O'), ('послушаем', 'VERB', 'root', 'O')],
#  [('пой', 'VERB', 'amod', 'O'),
#   ('капитан', 'NOUN', 'nsubj', 'B-BOOK'),
#   ('врунгел', 'NOUN', 'nmod', 'I-BOOK')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('You', 'PRON', 'appos', 'B-SONG'),
#   ('Should', 'AUX', 'flat:foreign', 'I-SONG'),
#   ('Be', 'AUX', 'flat:foreign', 'I-SONG'),
#   ('Dancing', 'VERB', 'flat:foreign', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O'), ('треть', 'NOUN', 'obj', 'B-FILM')],
#  [('давай', 'VERB', 'root', 'O'), ('виламатас', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('дома', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('ян', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('сибелиус', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('The', 'DET', 'appos', 'B-SINGER'),
#   ('Velvet', 'NOUN', 'flat:foreign', 'I-SINGER'),
#   ('Underground', 'ADV', 'flat:foreign', 'I-SINGER')],
#  [('вруби', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('эдвард', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('форстер', 'NOUN', 'root', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Bad', 'ADJ', 'appos', 'B-SONG'),
#   ('Romance', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('включи', 'VERB', 'root', 'O')],
#  [('воспроизведи', 'VERB', 'acl', 'O'),
#   ('композитора', 'NOUN', 'nmod', 'O'),
#   ('оффенбах', 'NOUN', 'nmod', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('но', 'CONJ', 'cc', 'B-SONG'),
#   ('же', 'PRCL', 'advmod', 'I-SONG')],
#  [('проиграй', 'VERB', 'acl', 'O'), ('наоборот', 'ADVB', 'advmod', 'B-BOOK')],
#  [('расскажи', 'VERB', 'root', 'O'), ('адаптац', 'NOUN', 'advmod', 'B-FILM')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('берджер', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('Anti', 'ADJ', 'appos', 'B-SINGER'),
#   ('Flag', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Une', 'NOUN', 'appos', 'B-SONG'),
#   ('Vie', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('DAmour', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('композитора', 'NOUN', 'nmod', 'O'),
#   ('римск', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('корсаков', 'NOUN', 'nmod', 'I-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('The', 'DET', 'xcomp', 'B-SINGER'),
#   ('Script', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Comme', 'ADJ', 'appos', 'B-SONG'),
#   ('Disait', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Mistinguett', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('синклэр', 'NOUN', 'advmod', 'B-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Have', 'AUX', 'appos', 'B-SONG'),
#   ('You', 'PRON', 'flat:foreign', 'I-SONG'),
#   ('Ever', 'ADV', 'flat:foreign', 'I-SONG'),
#   ('Really', 'ADV', 'flat:foreign', 'I-SONG'),
#   ('Loved', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('A', 'DET', 'flat:foreign', 'I-SONG'),
#   ('Woman', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('дмитр', 'NOUN', 'amod', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('алеся', 'NOUN', 'nmod', 'B-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('ReAnima', 'NOUN', 'appos', 'B-SINGER')],
#  [('вруби', 'VERB', 'amod', 'O'), ('ривар', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('два', 'NUMR', 'nsubj', 'B-BOOK'),
#   ('мороз', 'NOUN', 'nsubj', 'I-BOOK')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('эраунд', 'NOUN', 'nmod', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('красн', 'NOUN', 'obj', 'B-SINGER'),
#   ('дерево', 'NOUN', 'obj', 'I-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('никола', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('мясковск', 'NOUN', 'nsubj', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('ольг', 'NOUN', 'amod', 'B-SINGER'),
#   ('арефьев', 'NOUN', 'nmod', 'I-SINGER'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('клин', 'NOUN', 'amod', 'B-SONG'),
#   ('тагэза', 'NOUN', 'nmod', 'I-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('чэнс', 'NOUN', 'nmod', 'B-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('бастой', 'NOUN', 'nmod', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'), ('хауз', 'NOUN', 'obj', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('наутилус', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('помпилиус', 'NOUN', 'nsubj', 'I-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'), ('дорожку', 'NOUN', 'obj', 'O')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('стравинск', 'NOUN', 'obj', 'B-COMPOSER')],
#  [('включи', 'VERB', 'acl', 'O'),
#   ('счастливо', 'ADVB', 'advmod', 'B-FILM'),
#   ('число', 'NOUN', 'obj', 'I-FILM'),
#   ('слевина', 'NOUN', 'nmod', 'I-FILM')],
#  [('включи', 'VERB', 'root', 'O'), ('жамэ', 'NOUN', 'advmod', 'B-SONG')],
#  [('включи', 'VERB', 'amod', 'O'),
#   ('джозеф', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('фаррел', 'VERB', 'appos', 'I-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('рук', 'NOUN', 'nmod', 'B-SINGER'),
#   ('вверх', 'ADVB', 'advmod', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Stumblin', 'NOUN', 'appos', 'B-SONG'),
#   ('In', 'ADP', 'flat:foreign', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('яну', 'NOUN', 'amod', 'B-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Mourir', 'NOUN', 'appos', 'B-SONG'),
#   ('Sur', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Scene', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('вруби', 'VERB', 'acl', 'O'), ('хороший', 'ADJF', 'root', 'B-FILM')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('жорж', 'NOUN', 'appos', 'B-SINGER'),
#   ('амаду', 'NOUN', 'appos', 'I-SINGER')],
#  [('включи', 'VERB', 'amod', 'O'),
#   ('сара', 'NOUN', 'nsubj', 'B-SONG'),
#   ('перке', 'NOUN', 'root', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'root', 'O'),
#   ('Dont', 'AUX', 'appos', 'B-SONG'),
#   ('Cry', 'PART', 'flat:foreign', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'), ('Horizon', 'NOUN', 'appos', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('произведение', 'NOUN', 'obj', 'O'),
#   ('Les', 'PROPN', 'appos', 'B-SONG'),
#   ('Hommes', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('Qui', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Passent', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'), ('винтаж', 'NOUN', 'advmod', 'B-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('нэ', 'ADV', 'advmod', 'B-SONG'),
#   ('регрэт', 'NOUN', 'obl', 'I-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('джет', 'NOUN', 'obj', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('пёрселл', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('жизни', 'NOUN', 'nmod', 'B-SONG'),
#   ('струны', 'NOUN', 'nmod', 'I-SONG')],
#  [('включи', 'VERB', 'acl', 'O'), ('форсаж', 'NOUN', 'obj', 'B-FILM')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('Il', 'ADP', 'obj', 'B-SONG'),
#   ('Pleut', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Sur', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Bruxelles', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('морис', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('равел', 'NOUN', 'root', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('фаревэ', 'NOUN', 'nmod', 'B-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('гаэтано', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('доницетти', 'NOUN', 'nsubj', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('BB', 'ADP', 'appos', 'B-SINGER'),
#   ('King', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('фридерик', 'NOUN', 'root', 'B-COMPOSER'),
#   ('шопен', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('July', 'NOUN', 'appos', 'B-SONG'),
#   ('Morning', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('лоа', 'ADV', 'nmod', 'B-SINGER'),
#   ('лоа', 'NOUN', 'obl', 'I-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'), ('басилаунэ', 'NOUN', 'obl', 'B-SONG')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('александр', 'NOUN', 'appos', 'B-SINGER'),
#   ('вертинск', 'NOUN', 'nmod', 'I-SINGER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('Punk', 'NOUN', 'obj', 'B-SINGER'),
#   ('TV', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('иван', 'NOUN', 'appos', 'B-SINGER'),
#   ('вазов', 'ADJS', 'nmod', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('элен', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('ферранте', 'NOUN', 'appos', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('I', 'PRON', 'appos', 'B-SONG'),
#   ('Need', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('You', 'PRON', 'flat:foreign', 'I-SONG'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('ногган', 'NOUN', 'nmod', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('александр', 'NOUN', 'appos', 'B-SINGER'),
#   ('хемон', 'NOUN', 'nmod', 'I-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'), ('виагр', 'NOUN', 'obl', 'B-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('альфред', 'NOUN', 'appos', 'B-SINGER'),
#   ('дёблин', 'NOUN', 'appos', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('александр', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('тихонович', 'NOUN', 'appos', 'I-COMPOSER'),
#   ('гречанинов', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'amod', 'O'), ('хиэр', 'NOUN', 'advmod', 'B-SONG')],
#  [('проиграй', 'VERB', 'root', 'O'),
#   ('певца', 'NOUN', 'nmod', 'O'),
#   ('рей', 'NOUN', 'appos', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'), ('бэк', 'VERB', 'obj', 'B-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'), ('нублие', 'NOUN', 'advmod', 'B-SONG')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('индиан', 'NOUN', 'amod', 'B-FILM'),
#   ('джонс', 'NOUN', 'obj', 'I-FILM'),
#   ('в', 'PREP', 'case', 'I-FILM'),
#   ('поиск', 'NOUN', 'obl', 'I-FILM'),
#   ('утраченн', 'NOUN', 'amod', 'I-FILM'),
#   ('ковчег', 'NOUN', 'obj', 'I-FILM')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('дженет', 'NOUN', 'root', 'B-SINGER'),
#   ('уинтерсон', 'NOUN', 'nmod', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'), ('послушаем', 'VERB', 'root', 'O')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('ту', 'ADJF', 'det', 'B-SONG'),
#   ('лайв', 'NOUN', 'iobj', 'I-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('The', 'DET', 'appos', 'B-SINGER'),
#   ('Fray', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('дорожку', 'NOUN', 'obj', 'O'),
#   ('ун', 'NOUN', 'nsubj', 'B-SONG'),
#   ('ви', 'INTJ', 'advmod', 'I-SONG'),
#   ('дамур', 'NOUN', 'nmod', 'I-SONG')],
#  [('вруби', 'VERB', 'amod', 'O'), ('монамур', 'NOUN', 'advmod', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('на', 'PREP', 'case', 'B-SONG'),
#   ('кургане', 'NOUN', 'obl', 'I-SONG')],
#  [('проиграй', 'VERB', 'amod', 'O'), ('далимань', 'NOUN', 'advmod', 'B-SONG')],
#  [('пой', 'VERB', 'root', 'O')],
#  [('пой', 'VERB', 'acl', 'O'),
#   ('произведение', 'NOUN', 'obj', 'O'),
#   ('виват', 'INTJ', 'root', 'B-SONG'),
#   ('король', 'NOUN', 'nsubj', 'I-SONG')],
#  [('пой', 'VERB', 'nsubj', 'O'),
#   ('безумн', 'NOUN', 'root', 'B-FILM'),
#   ('макс', 'NOUN', 'nsubj', 'I-FILM'),
#   ('два', 'NUMR', 'advmod', 'I-FILM')],
#  [('зажги', 'VERB', 'nsubj', 'O'),
#   ('роберт', 'NOUN', 'root', 'B-COMPOSER'),
#   ('шуман', 'NOUN', 'nsubj', 'I-COMPOSER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('хьюго', 'NOUN', 'obj', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('сезар', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('франк', 'NOUN', 'amod', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('кам', 'NOUN', 'root', 'B-SONG'),
#   ('андан', 'PRTS', 'advmod', 'I-SONG')],
#  [('вруби', 'VERB', 'root', 'O'),
#   ('Il', 'ADP', 'appos', 'B-SONG'),
#   ('Pleut', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Sur', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Bruxelles', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('Always', 'ADV', 'appos', 'B-SONG'),
#   ('Somewhere', 'ADV', 'flat:foreign', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('без', 'PREP', 'case', 'B-FILM'),
#   ('лица', 'NOUN', 'obl', 'I-FILM')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('корелли', 'NOUN', 'advmod', 'B-COMPOSER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('ян', 'NOUN', 'appos', 'B-SINGER'),
#   ('мартел', 'NOUN', 'appos', 'I-SINGER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('пикник', 'NOUN', 'nmod', 'B-SINGER'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('Eagle', 'NOUN', 'appos', 'B-SONG')],
#  [('зажги', 'VERB', 'root', 'O'), ('дворжак', 'NOUN', 'nsubj', 'B-COMPOSER')],
#  [('пой', 'VERB', 'amod', 'O'),
#   ('александр', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('бородин', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'amod', 'O'), ('мертвец', 'NOUN', 'root', 'B-FILM')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('альберт', 'NOUN', 'nsubj', 'B-BOOK'),
#   ('и', 'CONJ', 'cc', 'I-BOOK'),
#   ('якоб', 'NOUN', 'conj', 'I-BOOK')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('хуан', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('гойтисол', 'NOUN', 'advmod', 'I-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('леош', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('яначек', 'NOUN', 'obj', 'I-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('падени', 'NOUN', 'xcomp', 'B-BOOK'),
#   ('дома', 'NOUN', 'advmod', 'I-BOOK'),
#   ('ашер', 'NOUN', 'nsubj', 'I-BOOK')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('тонк', 'NOUN', 'xcomp', 'B-SONG'),
#   ('рябина', 'NOUN', 'nsubj', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'root', 'O'),
#   ('Neutral', 'ADJ', 'appos', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('книгу', 'NOUN', 'obj', 'O'),
#   ('васили', 'NOUN', 'amod', 'B-BOOK'),
#   ('тёркин', 'NOUN', 'obl', 'I-BOOK')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('шапк', 'NOUN', 'obj', 'B-BOOK')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('песня', 'NOUN', 'nsubj', 'B-SONG')],
#  [('пой', 'VERB', 'root', 'O'), ('фаворит', 'NOUN', 'nsubj', 'B-BOOK')],
#  [('играй', 'VERB', 'root', 'O'), ('онеггер', 'NOUN', 'advmod', 'B-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('джозеф', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('хеллер', 'NOUN', 'punct', 'I-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('на', 'PREP', 'case', 'B-BOOK'),
#   ('маяк', 'NOUN', 'obl', 'I-BOOK')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('волшебниц', 'NOUN', 'obj', 'B-BOOK')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('пересреверт', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('рук', 'NOUN', 'obj', 'B-SINGER'),
#   ('вверх', 'ADVB', 'advmod', 'I-SINGER')],
#  [('проиграй', 'VERB', 'nsubj', 'O'),
#   ('композитора', 'NOUN', 'nmod', 'O'),
#   ('генрих', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('шютц', 'NOUN', 'root', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('ещё', 'ADVB', 'advmod', 'B-SONG')],
#  [('вруби', 'VERB', 'amod', 'O'), ('дэнэн', 'NOUN', 'advmod', 'B-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'), ('эво', 'NOUN', 'root', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('энэмэл', 'NOUN', 'obj', 'B-SINGER'),
#   ('калэктив', 'NOUN', 'obj', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('ниэунеит', 'NOUN', 'advmod', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('джулиан', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('барнс', 'NOUN', 'root', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Ich', 'NOUN', 'appos', 'B-SONG'),
#   ('Will', 'AUX', 'flat:foreign', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('приключени', 'NOUN', 'amod', 'B-BOOK'),
#   ('гекльберри', 'NOUN', 'obj', 'I-BOOK'),
#   ('финн', 'NOUN', 'appos', 'I-BOOK')],
#  [('вруби', 'VERB', 'amod', 'O'), ('бернстайн', 'NOUN', 'root', 'B-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'), ('малер', 'NOUN', 'nsubj', 'B-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Tu', 'PROPN', 'appos', 'B-SONG'),
#   ('Es', 'CCONJ', 'flat:foreign', 'I-SONG'),
#   ('Foutu', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('уэкс', 'NOUN', 'nmod', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('джаком', 'NOUN', 'obj', 'B-COMPOSER'),
#   ('пуччини', 'NOUN', 'nmod', 'I-COMPOSER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('сказка', 'NOUN', 'root', 'B-BOOK'),
#   ('о', 'PREP', 'case', 'I-BOOK')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('софи', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('асгатовн', 'NOUN', 'root', 'I-COMPOSER'),
#   ('губайдулин', 'NOUN', 'obj', 'I-COMPOSER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('спокойн', 'NOUN', 'xcomp', 'B-SONG'),
#   ('ночь', 'NOUN', 'nsubj', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('противостояни', 'NOUN', 'advmod', 'B-FILM')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('красно', 'ADJS', 'obj', 'B-BOOK'),
#   ('и', 'CONJ', 'cc', 'I-BOOK'),
#   ('чёрно', 'NOUN', 'conj', 'I-BOOK')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('велик', 'ADJS', 'nsubj', 'B-BOOK'),
#   ('гэтсби', 'NOUN', 'nsubj', 'I-BOOK')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('список', 'NOUN', 'obj', 'B-FILM'),
#   ('шиндлер', 'NOUN', 'nmod', 'I-FILM')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('рейда', 'NOUN', 'obj', 'B-FILM')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('Le', 'X', 'obj', 'B-SONG'),
#   ('Clown', 'VERB', 'flat:foreign', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('королевск', 'NOUN', 'root', 'B-BOOK'),
#   ('сказка', 'NOUN', 'amod', 'I-BOOK')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('исаак', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('осипович', 'NOUN', 'appos', 'I-COMPOSER'),
#   ('дунаевск', 'NOUN', 'obj', 'I-COMPOSER')],
#  [('включи', 'VERB', 'amod', 'O'),
#   ('гавриил', 'NOUN', 'obj', 'B-SINGER'),
#   ('троепольск', 'ADJF', 'amod', 'I-SINGER')],
#  [('играй', 'VERB', 'root', 'O'), ('рамо', 'NOUN', 'nsubj', 'B-COMPOSER')],
#  [('вруби', 'VERB', 'amod', 'O'), ('дальмань', 'NOUN', 'advmod', 'B-SONG')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('басков', 'NOUN', 'nmod', 'B-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('зонэ', 'NOUN', 'nmod', 'B-SONG')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('Equal', 'ADJ', 'obj', 'B-SINGER'),
#   ('Minds', 'NOUN', 'flat:foreign', 'I-SINGER'),
#   ('Theory', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('пой', 'VERB', 'nsubj', 'O'),
#   ('зор', 'NOUN', 'root', 'B-SINGER'),
#   ('нил', 'NOUN', 'nsubj', 'I-SINGER'),
#   ('хёрстон', 'NOUN', 'appos', 'I-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('песни', 'NOUN', 'obj', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('фильма', 'NOUN', 'nmod', 'O'),
#   ('воздушн', 'NOUN', 'root', 'B-FILM'),
#   ('маршал', 'NOUN', 'nsubj', 'I-FILM')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('James', 'NOUN', 'appos', 'B-SINGER'),
#   ('Blake', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('дамор', 'NOUN', 'advmod', 'B-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('гайдн', 'NOUN', 'obj', 'B-COMPOSER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('Sara', 'NOUN', 'nsubj', 'B-SONG'),
#   ('Perche', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Ti', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Amo', 'X', 'flat:foreign', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('фильм', 'NOUN', 'obj', 'O'),
#   ('джон', 'NOUN', 'appos', 'B-FILM'),
#   ('уик', 'VERB', 'appos', 'I-FILM'),
#   ('два', 'NUMR', 'flat:name', 'I-FILM')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('малена', 'NOUN', 'nsubj', 'B-FILM')],
#  [('проиграй', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('рёйксопп', 'NOUN', 'nmod', 'B-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('сториэ', 'NOUN', 'nmod', 'B-SONG'),
#   ('ди', 'PRCL', 'obj', 'I-SONG'),
#   ('тути', 'NOUN', 'nmod', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('станислав', 'NOUN', 'appos', 'B-COMPOSER'),
#   ('монюшко', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('вруби', 'VERB', 'amod', 'O'), ('килаз', 'NOUN', 'advmod', 'B-SINGER')],
#  [('вруби', 'VERB', 'amod', 'O'), ('дасаев', 'NOUN', 'appos', 'B-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('никола', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('метнер', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('карл', 'NOUN', 'appos', 'B-COMPOSER'),
#   ('мари', 'NOUN', 'appos', 'I-COMPOSER'),
#   ('фон', 'PRCL', 'appos', 'I-COMPOSER'),
#   ('вебер', 'NOUN', 'nsubj', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('звезды', 'NOUN', 'nmod', 'B-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('калинов', 'ADJS', 'amod', 'B-SINGER'),
#   ('мост', 'NOUN', 'nsubj', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'root', 'O'),
#   ('Una', 'NOUN', 'appos', 'B-SONG'),
#   ('Musica', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Brutal', 'ADV', 'flat:foreign', 'I-SONG')],
#  [('спой', 'VERB', 'nsubj', 'O'),
#   ('композитора', 'NOUN', 'nmod', 'O'),
#   ('джованни', 'NOUN', 'nmod', 'B-COMPOSER'),
#   ('палестрина', 'NOUN', 'root', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('лебедин', 'ADJS', 'nmod', 'B-SONG'),
#   ('верност', 'NOUN', 'obj', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'root', 'O'),
#   ('Et', 'X', 'appos', 'B-SONG'),
#   ('Si', 'X', 'flat:foreign', 'I-SONG'),
#   ('Tu', 'PROPN', 'flat:foreign', 'I-SONG'),
#   ('NExistais', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Pas', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('джованни', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('палестрина', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('Desert', 'NOUN', 'obj', 'B-SONG'),
#   ('Rose', 'VERB', 'flat:foreign', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O'), ('Amatory', 'ADJ', 'obj', 'B-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'), ('Rosenrot', 'VERB', 'obj', 'B-SONG')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('произведение', 'NOUN', 'obj', 'O'),
#   ('последне', 'ADJS', 'root', 'B-SONG'),
#   ('письм', 'NOUN', 'obj', 'I-SONG')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('солом', 'NOUN', 'amod', 'B-SINGER'),
#   ('беллоу', 'NOUN', 'appos', 'I-SINGER')],
#  [('воспроизводим', 'VERB', 'root', 'O'),
#   ('пером', 'NOUN', 'obl', 'B-SINGER'),
#   ('энквист', 'NOUN', 'obl', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('артур', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('онеггер', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('играй', 'VERB', 'root', 'O'), ('молекул', 'NOUN', 'nmod', 'B-SINGER')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Non', 'ADJ', 'appos', 'B-SONG'),
#   ('Je', 'X', 'flat:foreign', 'I-SONG'),
#   ('Ne', 'INTJ', 'flat:foreign', 'I-SONG'),
#   ('Regrette', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Rien', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('из', 'PREP', 'case', 'O'),
#   ('тузах', 'NOUN', 'nmod', 'B-FILM')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('певца', 'NOUN', 'obj', 'O'),
#   ('кемикл', 'NOUN', 'obl', 'B-SINGER')],
#  [('включи', 'VERB', 'root', 'O'), ('мэйар', 'NOUN', 'advmod', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'nmod', 'O'),
#   ('тринадцать', 'NUMR', 'nummod:gov', 'B-FILM'),
#   ('друзей', 'NOUN', 'nsubj', 'I-FILM')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('Et', 'NOUN', 'obj', 'B-SONG'),
#   ('Pourtant', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('J', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Ai', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('Froid', 'ADJ', 'flat:foreign', 'I-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('аними', 'ADJF', 'obj', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('рай', 'NOUN', 'obj', 'B-BOOK')],
#  [('включи', 'VERB', 'root', 'O'), ('ершов', 'ADJS', 'nsubj', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('Jordin', 'NOUN', 'obj', 'B-SINGER'),
#   ('Sparks', 'VERB', 'flat:foreign', 'I-SINGER')],
#  [('пой', 'VERB', 'root', 'O'), ('героя', 'NOUN', 'obj', 'B-FILM')],
#  [('давай', 'VERB', 'root', 'O'), ('дубцов', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('книгу', 'NOUN', 'obj', 'O'),
#   ('о', 'PREP', 'case', 'B-BOOK'),
#   ('любв', 'GRND', 'nmod', 'I-BOOK'),
#   ('и', 'CONJ', 'cc', 'I-BOOK'),
#   ('мрак', 'NOUN', 'conj', 'I-BOOK')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('трофимов', 'NOUN', 'appos', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'root', 'O'),
#   ('Je', 'PROPN', 'appos', 'B-SONG'),
#   ('Veux', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('проиграй', 'VERB', 'root', 'O'), ('Akado', 'NOUN', 'appos', 'B-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('луиз', 'NOUN', 'nmod', 'B-SINGER'),
#   ('мэй', 'NOUN', 'appos', 'I-SINGER'),
#   ('олкот', 'NOUN', 'amod', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('вореи', 'NOUN', 'nmod', 'B-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('порой', 'ADVB', 'advmod', 'B-BOOK'),
#   ('нестерпимо', 'ADJS', 'advmod', 'I-BOOK'),
#   ('хочется', 'VERB', 'csubj', 'I-BOOK')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('бригадн', 'NOUN', 'obl', 'B-SINGER'),
#   ('подряд', 'ADVB', 'advmod', 'I-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('фолкнер', 'NOUN', 'advmod', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('эль', 'PRCL', 'appos', 'B-SONG'),
#   ('бимбо', 'NOUN', 'appos', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('же', 'PRCL', 'advmod', 'B-SONG'),
#   ('круа', 'NOUN', 'amod', 'I-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('миюк', 'NOUN', 'nmod', 'B-SINGER'),
#   ('мияб', 'VERB', 'obj', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('сибелиус', 'NOUN', 'root', 'B-COMPOSER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('дорожку', 'NOUN', 'obj', 'O'),
#   ('я', 'NPRO', 'nsubj', 'B-SONG'),
#   ('люблю', 'VERB', 'root', 'I-SONG'),
#   ('тебя', 'NPRO', 'obj', 'I-SONG'),
#   ('жизнь', 'NOUN', 'obj', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
# ...
#   ('всяк', 'ADJS', 'obl', 'I-BOOK'),
#   ('мудрец', 'NOUN', 'root', 'I-BOOK'),
#   ('довольно', 'ADVB', 'advmod', 'I-BOOK'),
#   ('простоты', 'NOUN', 'obj', 'I-BOOK')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('абба', 'NOUN', 'nmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('пансион', 'NOUN', 'amod', 'B-BOOK'),
#   ('мирамар', 'NOUN', 'obj', 'I-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('книгу', 'NOUN', 'obj', 'O'),
#   ('силе', 'NOUN', 'iobj', 'B-BOOK'),
#   ('и', 'CONJ', 'cc', 'I-BOOK'),
#   ('слава', 'NOUN', 'conj', 'I-BOOK')],
#  [('включи', 'VERB', 'acl', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('верди', 'NOUN', 'nmod', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('ихь', 'NOUN', 'root', 'B-SONG'),
#   ('виль', 'NOUN', 'nmod', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('дурн', 'NOUN', 'obj', 'B-SINGER'),
#   ('влияни', 'VERB', 'obj', 'I-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('луч', 'NOUN', 'obj', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'), ('клевер', 'NOUN', 'nsubj', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('книгу', 'NOUN', 'obj', 'O'),
#   ('дики', 'ADJS', 'nsubj', 'B-BOOK'),
#   ('лебед', 'NOUN', 'appos', 'I-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('тихого', 'ADJF', 'obl', 'B-BOOK')],
#  [('воспроизводим', 'VERB', 'root', 'O'),
#   ('Hot', 'ADJ', 'appos', 'B-SINGER'),
#   ('Chip', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('йу', 'ADP', 'obj', 'B-SONG'),
#   ('эва', 'INTJ', 'nsubj', 'I-SONG')],
#  [('пой', 'VERB', 'root', 'O'), ('студжиз', 'NOUN', 'advmod', 'B-SINGER')],
#  [('пой', 'VERB', 'acl', 'O'),
#   ('гори', 'VERB', 'obj', 'B-SONG'),
#   ('гори', 'VERB', 'iobj', 'I-SONG'),
#   ('моя', 'ADJF', 'det', 'I-SONG'),
#   ('звезда', 'NOUN', 'nsubj', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('певца', 'NOUN', 'obj', 'O'),
#   ('Nancy', 'NOUN', 'appos', 'B-SINGER'),
#   ('Sinatra', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('вруби', 'VERB', 'amod', 'O'), ('бетховен', 'NOUN', 'appos', 'B-FILM')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('монюшко', 'NOUN', 'nmod', 'B-COMPOSER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('ту', 'ADJF', 'det', 'B-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('моторам', 'NOUN', 'nmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('король', 'NOUN', 'nsubj', 'B-BOOK')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('брет', 'NOUN', 'nmod', 'B-SINGER'),
#   ('эллис', 'NOUN', 'appos', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Je', 'NOUN', 'appos', 'B-SONG'),
#   ('Suis', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Malade', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('зажги', 'VERB', 'root', 'O')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('орбакайте', 'VERB', 'appos', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('Addio', 'NOUN', 'obj', 'B-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('Frank', 'ADJ', 'obj', 'B-SINGER'),
#   ('Zappa', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('давай', 'VERB', 'root', 'O'), ('штраус', 'NOUN', 'nsubj', 'B-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('умка', 'NOUN', 'obj', 'B-SINGER')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('франц', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('шуберт', 'NOUN', 'amod', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('это', 'PRCL', 'nmod', 'B-SONG'),
#   ('всё', 'PRCL', 'flat:name', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('александр', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('беляев', 'NOUN', 'nsubj', 'I-SINGER')],
#  [('зажги', 'VERB', 'nsubj', 'O'), ('мари', 'NOUN', 'xcomp', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('вивальди', 'NOUN', 'appos', 'B-COMPOSER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('композитора', 'NOUN', 'nmod', 'O'),
#   ('жаном', 'NOUN', 'nmod', 'B-COMPOSER'),
#   ('филипп', 'NOUN', 'appos', 'I-COMPOSER'),
#   ('рамо', 'NOUN', 'amod', 'I-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('сказочн', 'NOUN', 'nmod', 'B-SONG'),
#   ('тайг', 'NOUN', 'obj', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('арто', 'NOUN', 'root', 'B-SINGER'),
#   ('паасилин', 'NOUN', 'nsubj', 'I-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('переговорщик', 'NOUN', 'nsubj', 'B-FILM')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Lei', 'X', 'appos', 'B-SONG'),
#   ('Lei', 'X', 'flat:foreign', 'I-SONG'),
#   ('композитора', 'NOUN', 'nmod', 'O'),
#   ('сен', 'NOUN', 'appos', 'B-COMPOSER'),
#   ('санс', 'NOUN', 'nmod', 'I-COMPOSER')],
#  [('проиграй', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('аш', 'VERB', 'acl', 'B-SINGER'),
#   ('компани', 'NOUN', 'nsubj', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('мутар', 'NOUN', 'nmod', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('двенадцать', 'NUMR', 'nummod:gov', 'B-BOOK'),
#   ('месяц', 'NOUN', 'nsubj', 'I-BOOK')],
#  [('проиграй', 'VERB', 'amod', 'O'), ('далимани', 'NOUN', 'advmod', 'B-SONG')],
#  [('вруби', 'VERB', 'amod', 'O'),
#   ('соках', 'NOUN', 'root', 'B-BOOK'),
#   ('земли', 'NOUN', 'nmod', 'I-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('мэид', 'NOUN', 'amod', 'B-SINGER'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('Belle', 'NOUN', 'appos', 'B-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('Ploho', 'NOUN', 'obj', 'B-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'), ('рамо', 'NOUN', 'nmod', 'B-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('весн', 'NOUN', 'xcomp', 'B-SINGER'),
#   ('на', 'PREP', 'case', 'I-SINGER'),
#   ('улице', 'NOUN', 'obl', 'I-SINGER'),
#   ('карл', 'NOUN', 'nsubj', 'I-SINGER'),
#   ('юхан', 'NOUN', 'appos', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Insatiable', 'ADJ', 'appos', 'B-SONG')],
#  [('спой', 'VERB', 'root', 'O'), ('Solerrain', 'NOUN', 'appos', 'B-SINGER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('повест', 'NOUN', 'obj', 'B-BOOK'),
#   ('о', 'PREP', 'case', 'I-BOOK'),
#   ('жизни', 'NOUN', 'obl', 'I-BOOK')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('верди', 'NOUN', 'nmod', 'B-COMPOSER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('письм', 'NOUN', 'nmod', 'B-SONG'),
#   ('в', 'PREP', 'case', 'I-SONG'),
#   ('редакцию', 'NOUN', 'obl', 'I-SONG'),
#   ('телевизионной', 'ADJF', 'amod', 'I-SONG'),
#   ('передачи', 'NOUN', 'nmod', 'I-SONG'),
#   ('очевидное', 'ADJF', 'amod', 'I-SONG'),
#   ('невероятное', 'ADJF', 'obj', 'I-SONG'),
#   ('из', 'PREP', 'case', 'I-SONG'),
#   ('сумасшедшего', 'ADJF', 'nmod', 'I-SONG'),
#   ('дома', 'NOUN', 'advmod', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('богоматер', 'ADJS', 'root', 'B-BOOK'),
#   ('убийц', 'NOUN', 'obj', 'I-BOOK')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('эшен', 'PRTS', 'amod', 'B-SINGER'),
#   ('лайт', 'NOUN', 'amod', 'I-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('бель', 'NOUN', 'obj', 'B-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('краснознамённ', 'NOUN', 'advmod', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'), ('крэца', 'NOUN', 'advmod', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('песни', 'NOUN', 'obj', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('фильма', 'NOUN', 'nmod', 'O'),
#   ('игр', 'NOUN', 'nmod', 'B-FILM')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('Little', 'ADJ', 'appos', 'B-SINGER'),
#   ('Big', 'ADJ', 'flat:foreign', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('симон', 'NOUN', 'nsubj', 'B-SINGER'),
#   ('вестдейк', 'NOUN', 'appos', 'I-SINGER')],
#  [('проиграй', 'VERB', 'amod', 'O'),
#   ('астерикс', 'NOUN', 'appos', 'B-FILM'),
#   ('и', 'CONJ', 'cc', 'I-FILM'),
#   ('обеликс', 'NOUN', 'conj', 'I-FILM'),
#   ('клеопатр', 'NOUN', 'amod', 'I-FILM')],
#  [('спой', 'VERB', 'amod', 'O'), ('куа', 'NOUN', 'advmod', 'B-SONG')],
#  [('пой', 'VERB', 'root', 'O'), ('Origa', 'ADV', 'appos', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('Ice', 'NOUN', 'obj', 'B-SINGER'),
#   ('Cube', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('играй', 'VERB', 'root', 'O'), ('конфесса', 'GRND', 'advmod', 'B-SONG')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('гуно', 'NOUN', 'nmod', 'B-COMPOSER')],
#  [('пой', 'VERB', 'root', 'O'), ('тихоня', 'NOUN', 'advmod', 'B-FILM')],
#  [('играй', 'VERB', 'root', 'O'), ('пэрке', 'NOUN', 'advmod', 'B-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'), ('дио', 'ADJ', 'nsubj', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('габриел', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('форе', 'NOUN', 'nmod', 'I-COMPOSER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('гудзонск', 'NOUN', 'obj', 'B-FILM'),
#   ('ястреб', 'NOUN', 'obj', 'I-FILM')],
#  [('воспроизводим', 'VERB', 'root', 'O'),
#   ('deadmau', 'NOUN', 'appos', 'B-SINGER')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('мореи', 'NOUN', 'root', 'B-SINGER'),
#   ('ил', 'NOUN', 'nmod', 'I-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('джеми', 'VERB', 'obj', 'B-SINGER'),
#   ('онил', 'NOUN', 'obj', 'I-SINGER')],
#  [('включи', 'VERB', 'root', 'O'),
#   ('софи', 'NOUN', 'obj', 'B-COMPOSER'),
#   ('губайдулин', 'NOUN', 'advmod', 'I-COMPOSER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('Et', 'NOUN', 'appos', 'B-SONG'),
#   ('Pourtant', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('J', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Ai', 'VERB', 'flat:foreign', 'I-SONG'),
#   ('Froid', 'ADJ', 'flat:foreign', 'I-SONG')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('я', 'NPRO', 'nsubj', 'B-SONG'),
#   ('получил', 'VERB', 'root', 'I-SONG'),
#   ('эту', 'ADJF', 'det', 'I-SONG'),
#   ('роль', 'NOUN', 'obj', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'amod', 'O'),
#   ('серге', 'NOUN', 'root', 'B-COMPOSER'),
#   ('рахманинов', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('спой', 'VERB', 'amod', 'O'), ('эйнджэл', 'NOUN', 'advmod', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'), ('крис', 'NOUN', 'nsubj', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('пэрфекто', 'ADVB', 'root', 'B-SONG'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('зощенко', 'NOUN', 'nmod', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('афра', 'NOUN', 'advmod', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('двадцать', 'NUMR', 'nummod:gov', 'B-FILM'),
#   ('один', 'ADJF', 'nummod', 'I-FILM'),
#   ('грамм', 'NOUN', 'obj', 'I-FILM')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('автора', 'NOUN', 'obj', 'O'),
#   ('House', 'NOUN', 'appos', 'B-SINGER'),
#   ('Of', 'ADP', 'flat:foreign', 'I-SINGER'),
#   ('Pain', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('воспроизведи', 'VERB', 'acl', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('снайпер', 'NOUN', 'obl', 'B-FILM'),
#   ('песню', 'NOUN', 'nmod', 'O'),
#   ('While', 'SCONJ', 'appos', 'B-SONG'),
#   ('My', 'PRON', 'flat:foreign', 'I-SONG'),
#   ('Guitar', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Gently', 'ADV', 'flat:foreign', 'I-SONG'),
#   ('Weeps', 'VERB', 'flat:foreign', 'I-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'), ('BiopsyhoZ', 'NOUN', 'obj', 'B-SINGER')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('аудиокнигу', 'NOUN', 'obj', 'O'),
#   ('если', 'CONJ', 'mark', 'B-BOOK'),
#   ('не', 'PRCL', 'advmod', 'I-BOOK'),
#   ('тепер', 'NOUN', 'obl', 'I-BOOK')],
#  [('расскажи', 'VERB', 'root', 'O'), ('композитора', 'NOUN', 'obj', 'O')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'obj', 'O'),
#   ('мельниц', 'NOUN', 'obj', 'B-SINGER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('Mamma', 'NOUN', 'obj', 'B-SONG'),
#   ('Mia', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('воспроизведи', 'VERB', 'root', 'O'),
#   ('Tu', 'PROPN', 'appos', 'B-SONG'),
#   ('Es', 'X', 'flat:foreign', 'I-SONG'),
#   ('Foutu', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('играй', 'VERB', 'root', 'O'), ('казанов', 'NOUN', 'advmod', 'B-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('Tanha', 'VERB', 'nsubj', 'B-SONG'),
#   ('Shodam', 'PROPN', 'flat:foreign', 'I-SONG'),
#   ('El', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Bimbo', 'NOUN', 'flat:foreign', 'I-SONG')],
#  [('вруби', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('Sakura', 'ADJ', 'appos', 'B-SINGER'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('поплачь', 'VERB', 'root', 'B-SONG'),
#   ('о', 'PREP', 'case', 'I-SONG'),
#   ('нём', 'NPRO', 'obl', 'I-SONG')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('St', 'ADV', 'obj', 'B-SINGER'),
#   ('Petersburg', 'ADJ', 'flat:foreign', 'I-SINGER'),
#   ('Ska', 'NOUN', 'flat:foreign', 'I-SINGER'),
#   ('Jazz', 'NOUN', 'flat:foreign', 'I-SINGER'),
#   ('Review', 'NOUN', 'flat:foreign', 'I-SINGER')],
#  [('играй', 'VERB', 'root', 'O'), ('бэнни', 'NOUN', 'advmod', 'B-SINGER')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('никола', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('яковлевич', 'NOUN', 'appos', 'I-COMPOSER'),
#   ('мясковск', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('играй', 'VERB', 'root', 'O'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('All', 'DET', 'appos', 'B-SONG'),
#   ('Those', 'DET', 'flat:foreign', 'I-SONG'),
#   ('Years', 'NOUN', 'flat:foreign', 'I-SONG'),
#   ('Ago', 'ADP', 'flat:foreign', 'I-SONG'),
#   ('композитора', 'NOUN', 'appos', 'O')],
#  [('зажги', 'VERB', 'root', 'O'), ('аркону', 'NOUN', 'obl', 'B-SINGER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('идеальн', 'NOUN', 'acl', 'B-FILM'),
#   ('шторм', 'NOUN', 'obj', 'I-FILM'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('фэличит', 'VERB', 'nmod', 'B-SONG')],
#  [('расскажи', 'VERB', 'root', 'O'), ('стабом', 'NOUN', 'advmod', 'B-SINGER')],
#  [('воспроизводим', 'VERB', 'nsubj', 'O'),
#   ('никому', 'NPRO', 'iobj', 'B-SONG'),
#   ('тебя', 'NPRO', 'obj', 'I-SONG'),
#   ('я', 'NPRO', 'nsubj', 'I-SONG'),
#   ('не', 'PRCL', 'advmod', 'I-SONG'),
#   ('отдам', 'VERB', 'parataxis', 'I-SONG')],
#  [('пой', 'VERB', 'root', 'O'),
#   ('два', 'NUMR', 'nummod:gov', 'B-BOOK'),
#   ('плуг', 'NOUN', 'nsubj', 'I-BOOK')],
#  [('вруби', 'VERB', 'nsubj', 'O'),
#   ('автора', 'NOUN', 'nmod', 'O'),
#   ('конец', 'NOUN', 'root', 'B-SINGER'),
#   ('фильма', 'NOUN', 'nsubj', 'I-SINGER')],
#  [('пой', 'VERB', 'root', 'O'), ('муттэр', 'NOUN', 'advmod', 'B-SONG')],
#  [('пой', 'VERB', 'root', 'O'), ('руке', 'NOUN', 'obl', 'B-FILM')],
#  [('спой', 'VERB', 'amod', 'O'),
#   ('лео', 'NOUN', 'appos', 'B-COMPOSER'),
#   ('делиб', 'NOUN', 'appos', 'I-COMPOSER')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('из', 'PREP', 'case', 'O'),
#   ('дюна', 'NOUN', 'obl', 'B-FILM'),
#   ('песню', 'NOUN', 'obj', 'O'),
#   ('вуле', 'NOUN', 'root', 'B-SONG'),
#   ('ву', 'NOUN', 'obj', 'I-SONG')],
#  [('давай', 'VERB', 'root', 'O'),
#   ('включи', 'VERB', 'xcomp', 'O'),
#   ('двадцать', 'NUMR', 'nummod:gov', 'B-FILM'),
#   ('один', 'ADJF', 'nummod', 'I-FILM'),
#   ('грамм', 'NOUN', 'obj', 'I-FILM')],
#  [('давай', 'VERB', 'root', 'O'), ('нем', 'ADJS', 'advmod', 'B-SONG')],
#  [('проиграй', 'VERB', 'appos', 'O'), ('да', 'PRCL', 'cc', 'B-SONG')],
#  [('давай', 'VERB', 'root', 'O'), ('гайдн', 'NOUN', 'advmod', 'B-COMPOSER')],
#  [('воспроизводим', 'VERB', 'amod', 'O'),
#   ('георг', 'NOUN', 'amod', 'B-COMPOSER'),
#   ('гендел', 'VERB', 'appos', 'I-COMPOSER')],
#  [('расскажи', 'VERB', 'root', 'O'), ('муттэр', 'NOUN', 'advmod', 'B-SONG')],
#  [('зажги', 'VERB', 'root', 'O'),
#   ('композитора', 'NOUN', 'obj', 'O'),
#   ('людвиг', 'NOUN', 'nsubj', 'B-COMPOSER'),
#   ('ван', 'PRCL', 'appos', 'I-COMPOSER'),
#   ('бетховен', 'NOUN', 'flat:name', 'I-COMPOSER')],
#  [('давай', 'VERB', 'advmod', 'O'),
#   ('послушаем', 'VERB', 'root', 'O'),
#   ('согдиан', 'NOUN', 'obj', 'B-SINGER')],
#  [('расскажи', 'VERB', 'root', 'O'),
#   ('хаи', 'NOUN', 'amod', 'B-SONG'),
#   ('хоупс', 'NOUN', 'obl', 'I-SONG')],
#  ...]

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    relteg = sent[i][2]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
        'reltag': relteg,
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        relteg1 = sent[i-1][2]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
            '-1:reltag': relteg1,
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        relteg1 = sent[i+1][2]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
            '+1:reltag': relteg1,
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, reltag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, reltag, label in sent]

# %%
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

# %%
X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %%
X_train[0][1]
# Out:
# {'bias': 1.0,
#  'word.lower()': 'из',
#  'word[-3:]': 'из',
#  'word.isupper()': False,
#  'word.istitle()': False,
#  'word.isdigit()': False,
#  'postag': 'PREP',
#  'postag[:2]': 'PR',
#  'reltag': 'case',
#  '-1:word.lower()': 'спой',
#  '-1:word.istitle()': False,
#  '-1:word.isupper()': False,
#  '-1:postag': 'VERB',
#  '-1:postag[:2]': 'VE',
#  '-1:reltag': 'acl',
#  '+1:word.lower()': 'шоколад',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False,
#  '+1:postag': 'NOUN',
#  '+1:postag[:2]': 'NO',
#  '+1:reltag': 'obl'}

# %%
# ! pip install -U 'scikit-learn<0.24'

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=20,
    all_possible_transitions=False,
)
crf.fit(X_train, y_train)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# CRF(algorithm='lbfgs', all_possible_transitions=False, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=20)

# %%
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-BOOK</th>
#
#                 <th>I-BOOK</th>
#
#                 <th>B-COMPOSER</th>
#
#                 <th>I-COMPOSER</th>
#
#                 <th>B-FILM</th>
#
#                 <th>I-FILM</th>
#
#                 <th>B-SINGER</th>
#
#                 <th>I-SINGER</th>
#
#                 <th>B-SONG</th>
#
#                 <th>I-SONG</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.96%)" title="O &rArr; O">
#                             0.476
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.21%)" title="O &rArr; B-BOOK">
#                             2.173
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.56%)" title="O &rArr; B-COMPOSER">
#                             2.052
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 87.04%)" title="O &rArr; B-FILM">
#                             3.787
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 89.13%)" title="O &rArr; B-SINGER">
#                             2.946
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.79%)" title="O &rArr; B-SONG">
#                             3.077
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-SONG">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-BOOK</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 82.04%)" title="B-BOOK &rArr; I-BOOK">
#                             6.031
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; B-SONG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-BOOK &rArr; I-SONG">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-BOOK</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 82.96%)" title="I-BOOK &rArr; I-BOOK">
#                             5.598
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-COMPOSER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-FILM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-SINGER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; B-SONG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-BOOK &rArr; I-SONG">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-COMPOSER</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.86%)" title="B-COMPOSER &rArr; O">
#                             -0.118
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-COMPOSER &rArr; B-BOOK">
#                             0.0
#                         </td>
#
#                         <td style="backg

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-FILM',
#  'B-SONG',
#  'B-SINGER',
#  'I-SONG',
#  'I-SINGER',
#  'B-COMPOSER',
#  'I-COMPOSER',
#  'I-FILM',
#  'B-BOOK',
#  'I-BOOK']

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred,
                      average='weighted', labels=labels)
# Out:
# 0.5943094723945032

# %%
y_test
# Out:
# [['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-COMPOSER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-FILM', 'I-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-COMPOSER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-COMPOSER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SONG'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'B-COMPOSER'],
#  ['O', 'B-BOOK'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-BOOK'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-BOOK'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O',
#   'O',
#   'B-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-COMPOSER'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'O', 'O', 'O', 'B-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'O', 'B-COMPOSER'],
#  ['O', 'B-FILM'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-BOOK'],
#  ['O', 'O', 'B-FILM'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-FILM'],
#  ['O', 'O', 'B-FILM', 'O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'O',
#   'B-SINGER',
#   'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER', 'O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-BOOK'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-COMPOSER', 'O', 'B-SONG'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'O',
#   'B-COMPOSER',
#   'I-COMPOSER',
#   'I-COMPOSER'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'O', 'B-SINGER'],
#  ['O', 'B-FILM'],
#  ['O', 'O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-COMPOSER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O',
#   'O',
#   'B-FILM',
#   'I-FILM',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'O', 'B-FILM', 'O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'O', 'B-COMPOSER', 'I-COMPOSER', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'O', 'O', 'O', 'B-FILM'],
#  ['O', 'O', 'O', 'O', 'B-FILM'],
#  ['O',
#   'O',
#   'O',
#   'B-SINGER',
#   'I-SINGER',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-FILM'],
#  ['O', 'O', 'O', 'B-SONG'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER', 'I-COMPOSER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-FILM'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'O',
#   'B-FILM',
#   'I-FILM'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'O', 'B-FILM', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-FILM'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-FILM', 'I-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-COMPOSER', 'O', 'B-SONG'],
#  ['O', 'B-COMPOSER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-COMPOSER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-FILM', 'O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'O', 'B-COMPOSER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O',
#   'B-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK',
#   'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'O', 'O', 'B-SINGER', 'I-SINGER', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'O', 'B-FILM', 'I-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'O', 'B-SONG'],
#  ['O', 'B-SINGER'],
#  ['O',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'O',
#   'B-SINGER',
#   'I-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-COMPOSER', 'I-COMPOSER', 'O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-FILM', 'I-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-COMPOSER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER', 'I-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'B-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-FILM'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'O', 'B-COMPOSER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-FILM'],
#  ['O', 'B-FILM'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O',
#   'O',
#   'B-SINGER',
#   'I-SINGER',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'B-COMPOSER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'O', 'B-SONG', 'I-SONG', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-FILM'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-FILM', 'I-FILM'],
#  ['O', 'O', 'B-COMPOSER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SONG', 'I-SONG', 'O', 'B-FILM', 'I-FILM'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-BOOK'],
#  ['O', 'O', 'B-COMPOSER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-FILM', 'I-FILM'],
#  ['O',
#   'O',
#   'B-SINGER',
#   'I-SINGER',
#   'I-SINGER',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG'],
#  ['O', 'O', 'B-SONG', 'O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O',
#   'O',
#   'O',
#   'B-SINGER',
#   'I-SINGER',
#   'O',
#   'B-SONG',
#   'I-SONG',
#   'I-SONG',
#   'I-SONG'],
#  ['O', 'O', 'B-SINGER', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-COMPOSER', 'I-COMPOSER'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SONG'],
#  ['O', 'B-FILM'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-FILM', 'I-FILM', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER'],
#  ['O', 'B-COMPOSER'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'B-SINGER'],
#  ['O', 'B-SONG'],
#  ['O', 'B-BOOK', 'I-BOOK', 'I-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-SONG', 'I-SONG'],
#  ['O', 'B-SONG', 'I-SONG', 'I-SONG', 'I-SONG'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER'],
#  ['O', 'O', 'B-FILM', 'I-FILM', 'I-FILM', 'I-FILM', 'O', 'B-SONG'],
#  ['O', 'O', 'B-FILM'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'B-SINGER', 'I-SINGER'],
#  ['O', 'O', 'B-COMPOSER'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK'],
#  ['O', 'O', 'B-BOOK', 'I-BOOK']]

# %%
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#       B-BOOK      0.281     0.123     0.171        73
#       I-BOOK      0.214     0.101     0.137        89
#   B-COMPOSER      0.655     0.543     0.594        35
#   I-COMPOSER      0.600     0.714     0.652        21
#       B-FILM      0.463     0.362     0.407        69
#       I-FILM      0.359     0.475     0.409        59
#     B-SINGER      0.620     0.806     0.701       253
#     I-SINGER      0.686     0.653     0.669       147
#       B-SONG      0.715     0.655     0.684       165
#       I-SONG      0.759     0.870     0.811       192
#
#    micro avg      0.618     0.617     0.617      1103
#    macro avg      0.535     0.530     0.523      1103
# weighted avg      0.589     0.617     0.594      1103
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass labels=['B-BOOK', 'I-BOOK', 'B-COMPOSER', 'I-COMPOSER', 'B-FILM', 'I-FILM', 'B-SINGER', 'I-SINGER', 'B-SONG', 'I-SONG'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=100, 
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space, 
                        cv=10, 
                        verbose=1, 
                        n_jobs=-1, 
                        n_iter=50, 
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  1.2min finished
# RandomizedSearchCV(cv=10,
#                    estimator=CRF(algorithm='lbfgs',
#                                  all_possible_transitions=True,
#                                  keep_tempfiles=None, max_iterations=100),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'c1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x16854a4f0>,
#                                         'c2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x13f7e34f0>},
#                    scoring=make_scorer(flat_f1_score, average=weighted, labels=['B-FILM', 'B-SONG', 'B-SINGER', 'I-SONG', 'I-SINGER', 'B-COMPOSER', 'I-COMPOSER', 'I-FILM', 'B-BOOK', 'I-BOOK']),
#                    verbose=1)

# %%
# crf = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.002877533268880202, 'c2': 0.04559724830895078}
# best CV score: 0.771982061689148
# model size: 0.60M

# %% [markdown]
# (Лучший результат был примерно 0.776)

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#       B-BOOK      0.462     0.247     0.321        73
#       I-BOOK      0.528     0.315     0.394        89
#   B-COMPOSER      0.750     0.514     0.610        35
#   I-COMPOSER      0.733     0.524     0.611        21
#       B-FILM      0.630     0.420     0.504        69
#       I-FILM      0.526     0.508     0.517        59
#     B-SINGER      0.626     0.842     0.718       253
#     I-SINGER      0.628     0.782     0.697       147
#       B-SONG      0.753     0.667     0.707       165
#       I-SONG      0.821     0.833     0.827       192
#
#    micro avg      0.667     0.664     0.665      1103
#    macro avg      0.646     0.565     0.591      1103
# weighted avg      0.662     0.664     0.651      1103

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# B-SINGER -> I-SINGER 6.852154
# B-SONG -> I-SONG  6.251669
# I-SONG -> I-SONG  6.057899
# B-BOOK -> I-BOOK  5.511594
# B-FILM -> I-FILM  5.388728
# I-BOOK -> I-BOOK  5.308638
# I-FILM -> I-FILM  5.214553
# B-COMPOSER -> I-COMPOSER 4.242289
# I-SINGER -> I-SINGER 4.193667
# O      -> B-FILM  3.897535
# I-COMPOSER -> I-COMPOSER 3.541044
# O      -> B-SONG  3.162245
# O      -> B-SINGER 3.042782
# O      -> B-BOOK  1.940641
# O      -> B-COMPOSER 1.682725
# I-SONG -> O       0.780802
# B-SINGER -> O       0.526489
# O      -> O       0.315762
# I-SINGER -> O       0.262729
# B-COMPOSER -> O       0.011481
#
# Top unlikely transitions:
# I-SINGER -> I-FILM  -0.835057
# B-SONG -> I-SINGER -0.836433
# B-FILM -> I-SONG  -0.849482
# B-COMPOSER -> I-BOOK  -0.854179
# B-SINGER -> I-BOOK  -0.887077
# B-SINGER -> I-SONG  -0.929446
# I-SINGER -> I-COMPOSER -0.936750
# I-BOOK -> O       -0.974832
# B-COMPOSER -> B-COMPOSER -0.982678
# B-FILM -> I-BOOK  -1.000578
# B-SINGER -> I-COMPOSER -1.040957
# B-COMPOSER -> I-SINGER -1.050220
# B-BOOK -> O       -1.114232
# I-SONG -> I-SINGER -1.274356
# I-SINGER -> I-SONG  -1.380701
# O      -> I-COMPOSER -2.072749
# O      -> I-SONG  -2.113865
# O      -> I-SINGER -2.331340
# O      -> I-FILM  -2.391464
# O      -> I-BOOK  -2.409576

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))    

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
# 6.916881 B-SINGER -1:word.lower():автора
# 6.405713 B-SONG   -1:word.lower():песню
# 5.227783 B-COMPOSER -1:word.lower():композитора
# 4.786432 B-SINGER -1:word.lower():певца
# 4.106429 O        word[-3:]:ора
# 4.095130 B-FILM   -1:word.lower():фильм
# 3.871496 O        BOS
# 3.647503 B-FILM   word.lower():втор
# 3.625112 O        word.lower():песню
# 3.625112 O        word[-3:]:сню
# 3.532770 B-FILM   -1:word.lower():фильма
# 3.232909 B-BOOK   -1:word.lower():книгу
# 3.201462 O        word.lower():композитора
# 3.133674 B-BOOK   word.lower():разгром
# 3.092082 B-COMPOSER word.lower():листом
# 3.078853 O        word.lower():включи
# 3.078853 O        word[-3:]:ючи
# 3.065089 O        word[-3:]:игу
# 2.816466 B-SINGER word.lower():маикалсан
# 2.765500 B-FILM   word.lower():тора
# 2.752869 B-FILM   -1:word.lower():из
# 2.736680 B-BOOK   word.lower():одиночеств
# 2.710827 B-FILM   word.lower():бессонниц
# 2.705285 B-FILM   word.lower():малена
# 2.696054 B-COMPOSER word.lower():равел
# 2.683580 B-BOOK   word[-3:]:ках
# 2.644668 B-BOOK   word.lower():гавань
# 2.637464 B-COMPOSER word[-3:]:ком
# 2.634942 B-BOOK   word[-3:]:лик
# 2.619974 B-COMPOSER word[-3:]:ини
#
# Top negative:
# -0.812672 I-FILM   -1:word.lower():из
# -0.816420 B-SINGER postag:ADJF
# -0.845134 B-SONG   postag[:2]:NU
# -0.851343 I-SINGER word[-3:]:вич
# -0.853132 B-FILM   +1:reltag:root
# -0.876101 I-SONG   word.lower():из
# -0.876101 I-SONG   word[-3:]:из
# -0.892659 I-SONG   reltag:appos
# -0.901250 B-SINGER word[-3:]:рье
# -0.905847 B-SONG   postag:ADJF
# -0.923517 B-SINGER word[-3:]:ter
# -0.928096 B-SONG   reltag:case
# -0.936540 B-BOOK   reltag:appos
# -0.951096 B-SONG   -1:reltag:acl
# -0.963541 B-SONG   word[-3:]:ого
# -1.003058 B-SINGER word[-3:]:man
# -1.020649 B-SINGER word[-3:]:тор
# -1.111402 B-SINGER word[-3:]:ble
# -1.114453 B-SINGER -1:reltag:appos
# -1.116551 B-SINGER word[-3:]:ity
# -1.124127 O        -1:reltag:obj
# -1.159145 B-SINGER word[-3:]:нск
# -1.202069 B-SINGER word[-3:]:вен
# -1.227760 O        +1:word.lower():песню
# -1.298926 B-FILM   postag:PREP
# -1.345657 B-COMPOSER word.istitle()
# -1.360367 B-BOOK   word.istitle()
# -1.504818 B-SINGER word[-3:]:nny
# -1.657187 B-FILM   word.istitle()
# -1.711597 O        EOS
